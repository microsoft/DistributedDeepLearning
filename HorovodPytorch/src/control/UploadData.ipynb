# %%
import json

# %%
# !az login -o table

# %%
# !az account list -o table
# Out:
# Name                           CloudName    SubscriptionId                        State    IsDefault
# -----------------------------  -----------  ------------------------------------  -------  -----------
# Boston DS Dev                  AzureCloud   0ca618d2-22a8-413a-96d0-0f1b531129c3  Enabled
# Azure Internal - London        AzureCloud   1ba81249-8edd-4619-a486-3d28a2176aad  Enabled
# Team Danielle Internal         AzureCloud   edf507a2-6235-46c5-b560-fd463ba2e771  Enabled  True
# Visual Studio Enterprise       AzureCloud   fb11e9eb-22e1-4347-8d0a-84ef60157664  Enabled
# Boston Engineering             AzureCloud   bc4170f0-cc6e-49d2-ba65-bc00a7a4df6b  Enabled
# ADLTrainingMS                  AzureCloud   ace74b35-b0de-428b-a1d9-55459d7a6e30  Enabled
# PhillyExt                      AzureCloud   a20c82c7-4497-4d44-952a-3105f790e26b  Enabled
# Ads Eng Big Data Subscription  AzureCloud   d4231148-f093-4473-85de-8c4d19247495  Enabled
# ...

# %%
# !az account set -s "<YOURTEAM>"

# %%
GROUP_NAME='datasharerg'
LOCATION='eastus'
STORAGE_ACCOUNT_NAME='datasharesa'
CONTAINER_NAME='imagenet'

# %%
# !az group create -n $GROUP_NAME -o table -l $LOCATION
# Out:
# Using default 'eastus' for arg location
# Location    Name
# ----------  -----------
# eastus      datasharerg

# %%
json_data = !az storage account create -l $LOCATION -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME --sku Standard_LRS
print('Storage account {} provisioning state: {}'.format(STORAGE_ACCOUNT_NAME, json.loads(''.join(json_data))['provisioningState']))
# Out:
# Storage account datasharesa provisioning state: Succeeded

# %%
json_data = !az storage account keys list -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME
storage_account_key = json.loads(''.join(json_data))[0]['value']

# %%
# !az storage container create --name $CONTAINER_NAME --account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# {
#   "created": true
# }

# %%
# !az configure --defaults location=$LOCATION

# %%
# !az configure --defaults group=$GROUP_NAME

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                     CONTAINER_NAME,
                                                                     'train.tar.gz')

# %%
# !azcopy --source /mnt/imagenet/train.tar.gz \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet
# Out:
# =                                                                               [2018/04/14 14:43:38][WARNING] The command line "--source "/mnt/imagenet/train.tar.gz" --destination "https://datasharesa.blob.core.windows.net/imagenet/train.tar.gz" --dest-key ******" in the journal file "/home/mat/Microsoft/Azure/AzCopy/AzCopy.jnl" is different from your input.
#                                                                                [2018/04/14 14:43:40][WARNING] Incomplete operation with different command line detected at the journal directory "/home/mat/Microsoft/Azure/AzCopy".
# ...

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'train.csv')

# %%
# !azcopy --source /mnt/imagenet/train.csv \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 4 MB; Average Speed:423.95 KB/s.                          Finished: 0 file(s), 62.739 MB; Average Speed:5.36 MB/s.                       Finished: 1 file(s), 62.739 MB; Average Speed:4.51 MB/s.                                                                                                      Finished 1 of total 1 file(s).
#                                                                                [2018/04/14 14:59:27] Transfer summary:
# -----------------
# Total files transferred: 1
# Transfer successfully:   1
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.00:00:18

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'validation.tar.gz')

# %%
# !azcopy --source /mnt/imagenet/validation.tar.gz \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 4 MB; Average Speed:419.84 KB/s.                          Finished: 0 file(s), 148 MB; Average Speed:12.54 MB/s.                         Finished: 0 file(s), 500 MB; Average Speed:36.1 MB/s.                          Finished: 0 file(s), 1.012 GB; Average Speed:65.16 MB/s.                       Finished: 0 file(s), 1.137 GB; Average Speed:64.84 MB/s.                       Finished: 0 file(s), 1.637 GB; Average Speed:83.82 MB/s.                       Finished: 0 file(s), 1.672 GB; Average Speed:77.66 MB/s.                       Finished: 0 file(s), 2.078 GB; Average Speed:88.33 MB/s.                       Finished: 0 file(s), 2.648 GB; Average Speed:103.
# ...

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'validation.csv')

# %%
# !azcopy --source /mnt/imagenet/validation.csv \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 1.844 MB; Average Speed:207.39 KB/s.                      Finished: 1 file(s), 1.844 MB; Average Speed:169.18 KB/s.                                                                                                     Finished 1 of total 1 file(s).
#                                                                                [2018/04/14 15:01:02] Transfer summary:
# -----------------
# Total files transferred: 1
# Transfer successfully:   1
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.00:00:15

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'train')

# %%
# !azcopy --source /mnt/imagenet/train \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet --recursive
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 42.28 KB; Average Speed:4.26 KB/s.                        Finished: 1622 file(s), 189.129 MB; Average Speed:15.81 MB/s.                  Finished: 3032 file(s), 336.938 MB; Average Speed:24.05 MB/s.                  Finished: 4579 file(s), 541.24 MB; Average Speed:33.7 MB/s.                    Finished: 6173 file(s), 779.579 MB; Average Speed:43.05 MB/s.                  Finished: 7607 file(s), 962.557 MB; Average Speed:47.75 MB/s.                  Finished: 9510 file(s), 1.183 GB; Average Speed:54.59 MB/s.                    Finished: 10771 file(s), 1.351 GB; Average Speed:57.04 MB/s.                   Finished: 12920 file(s), 1.643 GB; Average Speed:
# ...

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'validation')

# %%
# !azcopy --source /mnt/imagenet/validation \
        --destination  $destination_url\
        --dest-key $storage_account_key --quiet --recursive
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 15.602 KB; Average Speed:1.56 KB/s.                       Finished: 1633 file(s), 203.104 MB; Average Speed:16.88 MB/s.                  Finished: 2603 file(s), 327.052 MB; Average Speed:23.23 MB/s.                  Finished: 4497 file(s), 572.907 MB; Average Speed:35.53 MB/s.                  Finished: 6046 file(s), 768.295 MB; Average Speed:42.27 MB/s.                  Finished: 6734 file(s), 861.13 MB; Average Speed:42.58 MB/s.                   Finished: 8198 file(s), 1.028 GB; Average Speed:47.25 MB/s.                    Finished: 9103 file(s), 1.138 GB; Average Speed:47.92 MB/s.                    Finished: 9485 file(s), 1.184 GB; Average Speed:4
# ...

# %%
# !az configure --defaults group=''
# !az configure --defaults location=''

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n validation.csv --permission r --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=7x3rN7c/nlXbnZ0gAFywd5Er3r6MdwCq97Vwvda25WE%3D"

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n validation.tar.gz --permission r --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=zy8L4shZa3XXBe152hPnhXsyfBqCufDOz01a9ZHWU28%3D"

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n train.csv --permission r --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=EUcahDDZcefOKtHoVWDh7voAC1BoxYNM512spFmjmDU%3D"

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n train.tar.gz --permission rw --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=rw&sv=2017-04-17&sr=b&sig=ZvNReeGrtDS28Cs/0P08tzFMsmDa3mq5dBRnQPc35DM%3D"

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n train --permission r --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=b1TyqISUPFbth6YhJNKtSgww8dhhM9jUpu7rsORmH2o%3D"

# %%
# !az storage blob generate-sas -c $CONTAINER_NAME  -n validation --expiry 2025-1-1  \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME

# %%
# !az storage container generate-sas --help
# Out:
# Command
#     az storage container generate-sas: Generates a shared access signature for the container.
#         Use the returned signature with the sas_token parameter of any BlobService.
#
# Arguments
#     --name -n  [Required]: The container name.
#     --cache-control      : Response header value for Cache-Control when resource is accessed using
#                            this shared access signature.
#     --content-disposition: Response header value for Content-Disposition when resource is accessed
#                            using this shared access signature.
#     --content-encoding   : Response header value for Content-Encoding when resource is accessed
#                            using this shared access signature.
#     --content-language   : Response header value for Content-Language when resource is accessed
#                            using this shared access signature.
# ...

# %%
# !az storage container generate-sas -n $CONTAINER_NAME --expiry 2025-1-1 --permissions lr \
--account-key $storage_account_key --account-name $STORAGE_ACCOUNT_NAME
# Out:
# "se=2025-01-01&sp=rl&sv=2017-04-17&sr=c&sig=AHbrRTNs7%2B%2BFi3rL%2BHs%2BbYjXDZLPWiXgWQwuhwmEo0A%3D"

# %%
STORAGE_ACCOUNT_NAME
# Out:
# 'datasharesa'

# %%
CONTAINER_NAME
# Out:
# 'imagenet'

# %%
https://datasharesa.blob.core.windows.net/imagenet?restype=container&comp=list&se=2025-01-01&sp=rl&sv=2017-04-17&sr=c&sig=AHbrRTNs7%2B%2BFi3rL%2BHs%2BbYjXDZLPWiXgWQwuhwmEo0A%3D
# Out:
#   File "<ipython-input-39-e20aa33da76f>", line 1
#     https://datasharesa.blob.core.windows.net/imagenet?restype=container&comp=list&se=2025-01-01&sp=rl&sv=2017-04-17&sr=c&sig=AHbrRTNs7%2B%2BFi3rL%2BHs%2BbYjXDZLPWiXgWQwuhwmEo0A%3D
#          ^
# SyntaxError: invalid syntax

# %%
https://datasharesa.blob.core.windows.net/imagenet/train.csv?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=7x3rN7c/nlXbnZ0gAFywd5Er3r6MdwCq97Vwvda25WE%3D
