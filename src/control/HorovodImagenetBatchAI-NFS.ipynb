# %%
# !az login -o table
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code ABNVKQJ47 to authenticate.
# CloudName    Name                           State    TenantId                              IsDefault
# -----------  -----------------------------  -------  ------------------------------------  -----------
# AzureCloud   Boston DS Dev                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Azure Internal - London        Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Danielle Internal         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47  True
# AzureCloud   Visual Studio Enterprise       Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Boston Engineering             Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   ADLTrainingMS                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyExt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Ads Eng Big Data Subscription  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling Preview         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling development     Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   AzureML Client PROD            Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   R portal - Production          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyInt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Project Vienna Demo 1          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Solution Template Testing      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Ilan                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Marketing Automation           Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47

# %%
# !az provider register -n Microsoft.BatchAI
# !az provider register -n Microsoft.Batch

# %%
# !az account list -o table
# Out:
# Name                           CloudName    SubscriptionId                        State    IsDefault
# -----------------------------  -----------  ------------------------------------  -------  -----------
# Boston DS Dev                  AzureCloud   0ca618d2-22a8-413a-96d0-0f1b531129c3  Enabled
# Azure Internal - London        AzureCloud   1ba81249-8edd-4619-a486-3d28a2176aad  Enabled
# Team Danielle Internal         AzureCloud   edf507a2-6235-46c5-b560-fd463ba2e771  Enabled  True
# Visual Studio Enterprise       AzureCloud   fb11e9eb-22e1-4347-8d0a-84ef60157664  Enabled
# Boston Engineering             AzureCloud   bc4170f0-cc6e-49d2-ba65-bc00a7a4df6b  Enabled
# ADLTrainingMS                  AzureCloud   ace74b35-b0de-428b-a1d9-55459d7a6e30  Enabled
# Data Wrangling Preview         AzureCloud   215613ac-9dfb-488c-be46-c387e999b127  Enabled
# Data Wrangling development     AzureCloud   35f16a99-532a-4a47-9e93-00305f6c40f2  Enabled
# AzureML Client PROD            AzureCloud   4a0f8d7f-c197-476b-95e1-fafcd77f12e4  Enabled
# R portal - Production          AzureCloud   2569dcd9-a995-4b78-ae22-58a1015fd0f7  Enabled
# PhillyExt                      AzureCloud   a20c82c7-4497-4d44-952a-3105f790e26b  Enabled
# Solution Template Testing      AzureCloud   3bcfa59c-82a0-44f9-ac08-b3479370bace  Enabled
# Team Ilan                      AzureCloud   ff18d7a8-962a-406c-858f-49acd23d6c01  Enabled
# Marketing Automation           AzureCloud   03909a66-bef8-4d52-8e9a-a346604e0902  Enabled
# Ads Eng Big Data Subscription  AzureCloud   d4231148-f093-4473-85de-8c4d19247495  Enabled
# PhillyInt                      AzureCloud   d50e5f6b-6c27-4ab1-8587-3d85cef6426e  Enabled
# Project Vienna Demo 1          AzureCloud   75f78a03-482f-4fd8-8c71-5ddc08f92726  Enabled
# UST Container Registration     AzureCloud   1f65a667-2b81-49ca-aea3-f8dd9fd3e1d9  Enabled
# ASutton Subscription           AzureCloud   10d0b7c6-9243-4713-91a9-2730375d3a1b  Enabled

# %%
# !az account set -s "<YOURTEAM>"

# %%
# !az --version
# Out:
# azure-cli (2.0.24)
#
# acr (2.0.18)
# acs (2.0.23)
# advisor (0.1.1)
# appservice (0.1.23)
# backup (1.0.4)
# batch (3.1.8)
# batchai (0.1.4)
# billing (0.1.7)
# cdn (0.0.11)
# cloud (2.0.11)
# cognitiveservices (0.1.10)
# command-modules-nspkg (2.0.1)
# configure (2.0.13)
# consumption (0.2.1)
# container (0.1.16)
# core (2.0.24)
# cosmosdb (0.1.16)
# dla (0.0.16)
# dls (0.0.19)
# eventgrid (0.1.7)
# extension (0.0.7)
# feedback (2.0.7)
# find (0.2.8)
# interactive (0.3.12)
# iot (0.1.16)
# keyvault (2.0.16)
# lab (0.0.14)
# monitor (0.0.14)
# network (2.0.20)
# nspkg (3.0.1)
# profile (2.0.17)
# rdbms (0.0.10)
# redis (0.2.11)
# reservations (0.1.1)
# resource (2.0.20)
# role (2.0.16)
# servicefabric (0.0.8)
# sql (2.0.18)
# storage (2.0.22)
# vm (2.0.23)
#
# Python location '/opt/az/bin/python3'
# Extensions directory '/home/mat/.azure/cliextensions'
#
# Python (Linux) 3.6.1 (default, Jan  5 2018, 21:18:08)
# [GCC 4.8.4]
#
# Legal docs and information: aka.ms/AzureCliLegal

# %%
import os
import uuid
import random
import json

def write_json_to_file(json_dict, filename):
    """ Simple function to write JSON dictionaries to files
    """
    with open(filename, 'w') as outfile:
        json.dump(json_dict, outfile)

LOCATION = 'eastus' # We are setting everything up in East US
                    # Be aware that you need to set things up in a region that has GPU VMs (N-Series)

# short_uuid = str(uuid.uuid4())[:8]
short_uuid = 'fcab5890'
GROUP_NAME = "batch{uuid}rg".format(uuid=short_uuid)
STORAGE_ACCOUNT_NAME = "batch{uuid}st".format(uuid=short_uuid)
CONTAINER_NAME = "batch{uuid}container".format(uuid=short_uuid)
FILESHARE_NAME = "batch{uuid}share".format(uuid=short_uuid)
NFS_NAME="batch{uuid}nfs".format(uuid=short_uuid)

# %%
# !az group create -n $GROUP_NAME -o table -l $LOCATION
# Out:
# Using default 'eastus' for arg location
# Location    Name
# ----------  ---------------
# eastus      batch6c03bc15rg

# %%
json_data = !az storage account create -l $LOCATION -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME --sku Standard_LRS
print('Storage account {} provisioning state: {}'.format(STORAGE_ACCOUNT_NAME, json.loads(''.join(json_data))['provisioningState']))
# Out:
# Storage account batchfcab5890st provisioning state: Succeeded

# %%
json_data = !az storage account keys list -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME
storage_account_key = json.loads(''.join(json_data))[0]['value']

# %%
# !az storage share create --account-name $STORAGE_ACCOUNT_NAME \
--account-key $storage_account_key --name $FILESHARE_NAME
# Out:
# {
#   "created": false
# }

# %%
# !az storage directory create --share-name $FILESHARE_NAME  --name scripts \
--account-name $STORAGE_ACCOUNT_NAME --account-key $storage_account_key
# Out:
# {
#   "created": true
# }

# %%
# !az configure --defaults location=$LOCATION

# %%
# !az configure --defaults group=$GROUP_NAME

# %%
# %env AZURE_STORAGE_ACCOUNT $STORAGE_ACCOUNT_NAME
# Out:
# env: AZURE_STORAGE_ACCOUNT=batchfcab5890st

# %%
# %env AZURE_STORAGE_KEY=$storage_account_key
# Out:
# env: AZURE_STORAGE_KEY=qTUeM/dh+vIhiKcrYx3EkvJKEOACztR2D7GAxE/5bRXnkxdU1T3e1JyYmbL4Rr43AMt6NMYW3OXPrg0iiyLk1g==

# %% [markdown]
# If you get an error when creating the NFS share below about permissions please run the command below
# ```bash
# !az role assignment create --scope /subscriptions/<YOUR SUBSRIPTION ID> --role "Network Contributor" --assignee 9fcb3732-5f52-4135-8c08-9d4bbaf203ea
# ```

# %%
# !az batchai file-server create -n $NFS_NAME --disk-count 4 --disk-size 250 -s Standard_DS4_v2 -u mat -p d13NHAL! -g $GROUP_NAME -l $LOCATION
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "creationTime": "2018-05-13T19:07:20.915000+00:00",
#   "dataDisks": {
#     "cachingType": "none",
#     "diskCount": 4,
#     "diskSizeInGb": 250,
#     "storageAccountType": "Premium_LRS"
#   },
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#   "location": "eastus",
#   "mountSettings": {
#     "fileServerInternalIp": "10.0.0.4",
#     "fileServerPublicIp": "40.114.69.36",
#     "fileServerType": "nfs",
#     "mountPoint": "/data"
#   },
#   "name": "batchfcab5890nfs",
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-13T19:11:30.794000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "sshConfiguration": {
#     "publicIpsToAllow": null,
#     "userAccountSettings": {
#       "adminUserName": "mat",
#       "adminUserPassword": null,
#       "adminUserSshPublicKey": null
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/FileServers",
#   "vmSize": "Standard_DS4_v2"
# }

# %%
# !az batchai file-server list -o table -g ""
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name              Resource Group    Size             Disks       Public IP     Internal IP    Type    Mount Point
# ----------------  ----------------  ---------------  ----------  ------------  -------------  ------  -------------
# batchfcab5890nfs  batchfcab5890rg   Standard_DS4_v2  4 x 250 Gb  40.114.69.36  10.0.0.4       nfs     /data

# %%
# %%writefile nodeprep.sh
# #!/usr/bin/env bash
# wget https://gist.githubusercontent.com/msalvaris/073c28a9993d58498957294d20d74202/raw/916eefe763c71da49d8ed41cb8474bdc8021af33/install_azcopy
# chmod 777 install_azcopy
# sudo ./install_azcopy
#
# mkdir -p /data/imagenet
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation.csv \
#         --destination  /data/imagenet/validation.csv\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=7x3rN7c/nlXbnZ0gAFywd5Er3r6MdwCq97Vwvda25WE%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation.tar.gz \
#         --destination  /data/imagenet/validation.tar.gz\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=zy8L4shZa3XXBe152hPnhXsyfBqCufDOz01a9ZHWU28%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train.csv \
#         --destination  /data/imagenet/train.csv\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=EUcahDDZcefOKtHoVWDh7voAC1BoxYNM512spFmjmDU%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train.tar.gz \
#         --destination  /data/imagenet/train.tar.gz\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=qP%2B7lQuFKHo5UhQKpHcKt6p5fHT21lPaLz1O/vv4FNU%3D"\
#         --quiet
#
# cd /data/imagenet
# tar -xvzf train.tar.gz
# tar -xzvf validation.tar.gz
# Out:
# Overwriting nodeprep.sh

# %% [markdown]
# Copy the file over and run it on the NFS VM. This will install azcopy and download and prepare the data
# ```bash
# scp nodeprep.sh mat@<VM_IP>:~/
# ssh mat@<VM_IP> sudo chmod 777 ~/nodeprep.sh
# ssh mat@<VM_IP> ./nodeprep.sh
# ```

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/ImagenetEstimatorHorovod.py --path scripts

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/timer.py --path scripts

# %%
# !az batchai cluster create \
--name nc24r \
--image UbuntuLTS \
--vm-size Standard_NC24r \
--min 2 --max 2 \
--afs-name $FILESHARE_NAME \
--afs-mount-path extfs \
--user-name mat \
--password dnstvxrz \
--storage-account-name $STORAGE_ACCOUNT_NAME \
--storage-account-key $storage_account_key \
--nfs $NFS_NAME \
--nfs-mount-path nfs
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "allocationState": "resizing",
#   "allocationStateTransitionTime": "2018-05-16T17:38:04.284000+00:00",
#   "creationTime": "2018-05-16T17:38:04.284000+00:00",
#   "currentNodeCount": 0,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": null,
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": [
#         {
#           "fileServer": {
#             "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#             "resourceGroup": "batchfcab5890rg"
#           },
#           "mountOptions": "rw",
#           "relativeMountPath": "nfs",
#           "sourceDirectory": null
#         }
#       ],
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 0,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-16T17:38:06.074000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 2
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster show -n nc24r
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# {
#   "allocationState": "resizing",
#   "allocationStateTransitionTime": "2018-05-16T17:38:04.284000+00:00",
#   "creationTime": "2018-05-16T17:38:04.284000+00:00",
#   "currentNodeCount": 0,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": null,
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": [
#         {
#           "fileServer": {
#             "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#             "resourceGroup": "batchfcab5890rg"
#           },
#           "mountOptions": "rw",
#           "relativeMountPath": "nfs",
#           "sourceDirectory": null
#         }
#       ],
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 0,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-16T17:38:06.074000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 2
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group

# %%
# !az batchai cluster list-nodes -n nc24r -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# The Resource 'Microsoft.BatchAI/clusters/nc24r' under resource group 'batchfcab5890rg' was not found.

# %%
jobs_dict = {
  "$schema": "https://raw.githubusercontent.com/Azure/BatchAI/master/schemas/2017-09-01-preview/job.json",
  "properties": {
    "nodeCount": 6,
    "customToolkitSettings": {
      "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh; \
      echo $AZ_BATCH_HOST_LIST; \
      mpirun -n 24 -ppn 4 -hosts $AZ_BATCH_HOST_LIST \
      -env I_MPI_FABRICS=dapl \
      -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0 \
      -env I_MPI_DYNAMIC_CONNECTION=0 \
      -env DISTRIBUTED=True \
      -genvall \
      python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetEstimatorHorovod.py"
    },
    "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
    "inputDirectories": [{
        "id": "SCRIPTS",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
      },
      {
        "id": "TRAIN",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet",
      },
      {
        "id": "TEST",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet",
      },
    ],
    "outputDirectories": [{
        "id": "MODEL",
        "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
        "pathSuffix": "Models"
    }],
    "containerSettings": {
      "imageSourceRegistry": {
        "image": "masalvar/horovod-intel"
      }
    }
  }
}

# %%
write_json_to_file(jobs_dict, 'job.json')

# %%
# !az batchai job create -n horovod_benchmark --cluster-name nc24r -c job.json
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "caffeSettings": null,
#   "chainerSettings": null,
#   "cluster": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#     "resourceGroup": "batchfcab5890rg"
#   },
#   "cntkSettings": null,
#   "constraints": {
#     "maxWallClockTime": "7 days, 0:00:00"
#   },
#   "containerSettings": {
#     "imageSourceRegistry": {
#       "credentials": null,
#       "image": "masalvar/horovod-intel",
#       "serverUrl": null
#     }
#   },
#   "creationTime": "2018-05-14T13:19:40.954000+00:00",
#   "customToolkitSettings": {
#     "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh;       echo $AZ_BATCH_HOST_LIST;       mpirun -n 24 -ppn 4 -hosts $AZ_BATCH_HOST_LIST       -env I_MPI_FABRICS=dapl       -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0       -env I_MPI_DYNAMIC_CONNECTION=0       -env DISTRIBUTED=True       -genvall       python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetEstimatorHorovod.py"
#   },
#   "environmentVariables": null,
#   "executionInfo": {
#     "endTime": null,
#     "errors": null,
#     "exitCode": null,
#     "startTime": "2018-05-14T13:19:43.751000+00:00"
#   },
#   "executionState": "running",
#   "executionStateTransitionTime": "2018-05-14T13:19:43.915000+00:00",
#   "experimentName": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/jobs/horovod_benchmark",
#   "inputDirectories": [
#     {
#       "id": "SCRIPTS",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
#     },
#     {
#       "id": "TRAIN",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet"
#     },
#     {
#       "id": "TEST",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet"
#     }
#   ],
#   "jobPreparation": null,
#   "location": null,
#   "name": "horovod_benchmark",
#   "nodeCount": 6,
#   "outputDirectories": [
#     {
#       "createNew": true,
#       "id": "MODEL",
#       "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#       "pathSuffix": "Models",
#       "type": "custom"
#     }
#   ],
#   "priority": 0,
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-14T13:19:41.822000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#   "tags": null,
#   "tensorFlowSettings": null,
#   "toolType": "custom",
#   "type": "Microsoft.BatchAI/Jobs"
# }

# %%
 # !az batchai job list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name               Resource Group    Cluster    Cluster RG       Tool      Nodes  State        Exit code
# -----------------  ----------------  ---------  ---------------  ------  -------  ---------  -----------
# horovod_benchmark  batchfcab5890rg   nc24r      batchfcab5890rg  custom        6  succeeded            0

# %%
# !az batchai job list-files --name horovod_benchmark --output-directory-id stdouterr
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# [
#   {
#     "contentLength": 2462,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_1-20180513t202449z.log?sv=2016-05-31&sr=f&sig=WhzRSyYFzOC3OPxgfEq%2Fbwru%2FotU9iF7vmcaCnF2p4A%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:48:51+00:00",
#     "name": "execution-tvm-325613345_1-20180513t202449z.log"
#   },
#   {
#     "contentLength": 2494,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_2-20180513t202449z.log?sv=2016-05-31&sr=f&sig=p%2Biz7DwPjyzClex%2FvWlP%2FlKvOFsd3AY0ekGscML%2FLbU%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:48:54+00:00",
#     "name": "execution-tvm-325613345_2-20180513t202449z.log"
#   },
#   {
#     "contentLength": 2417,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_3-20180513t202449z.log?sv=2016-05-31&sr=f&sig=%2BjjYk9yLqO3iARnnz0zOdqKIWh69mX9DessSzHni1po%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:49:04+00:00",
#     "name": "execution-tvm-325613345_3-20180513t202449z.log"
#   },
#   {
#     "contentLength": 2364,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_4-20180513t202449z.log?sv=2016-05-31&sr=f&sig=SFtgeUlp%2F0G93V%2BePrWiP%2Fe3B1jN7QC2DBxM%2BmJgVP8%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:48:56+00:00",
#     "name": "execution-tvm-325613345_4-20180513t202449z.log"
#   },
#   {
#     "contentLength": 2407,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_5-20180513t202449z.log?sv=2016-05-31&sr=f&sig=RHTRbQcptzpho3X8qXJPxud6JkjjdKsDRH4hYR6iEDQ%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:48:56+00:00",
#     "name": "execution-tvm-325613345_5-20180513t202449z.log"
#   },
#   {
#     "contentLength": 2307,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/94869bac-d0cc-4b14-9c4b-a06dbd3d34f6/execution-tvm-325613345_6-20180513t202449z.log?sv=2016-05-31&sr=f&sig=%2Bb09%2BrO8kJaX5ls5GPubOtcs%2FIgs22pJTfCSoeF%2Bk24%3D&se=2018-05-13T21%3A49%3A06Z&sp=rl",
#     "lastModified": "2018-05-13T20:48:51+00:00",
#     "name": "execution-tvm-325613345_6-20180513t202449z.log"
#   }
# ]

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stderr.txt
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_global_id_in_cluster': 0, '_save_checkpoints_steps': 10000, '_keep_checkpoint_max': 5, '_log_step_count_steps': 100, '_tf_random_seed': None, '_master': '', '_task_id': 0, '_evaluation_master': '', '_save_checkpoints_secs': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f941bb522e8>, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_keep_checkpoint_every_n_hours': 10000, '_num_worker_replicas': 1, '_service': None, '_is_chief': True, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_task_type': 'worker'}
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_global_id_in_cluster': 0, '_task_type': 'worker', '_num_worker_replicas': 1, '_log_step_count_steps': 100, '_task_id': 0, '_master': '', '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f43701102e8>, '_save_checkpoints_steps': 10000, '_evaluation_master': '', '_keep_checkpoint_max': 5, '_is_chief': True, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_service': None, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None, '_num_ps_replicas': 0}
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_save_summary_steps': 100, '_save_checkpoints_secs': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f13a5ad0390>, '_is_chief': True, '_evaluation_master': '', '_task_id': 0, '_task_type': 'worker', '_save_checkpoints_steps': 10000, '_keep_checkpoint_max': 5, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_tf_random_seed': None, '_log_step_count_steps': 100, '_master': '', '_global_id_in_cluster': 0, '_service': None, '_keep_checkpoint_every_n_hours': 10000}
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_service': None, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_evaluation_master': '', '_log_step_count_steps': 100, '_save_summary_steps': 100, '_is_chief': True, '_num_worker_replicas': 1, '_save_checkpoints_steps': 10000, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8fb91102b0>, '_save_checkpoints_secs': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_tf_random_seed': None, '_task_type': 'worker', '_num_ps_replicas': 0, '_task_id': 0, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_master': '', '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_log_step_count_steps': 100, '_save_checkpoints_steps': 10000, '_global_id_in_cluster': 0, '_task_id': 0, '_evaluation_master': '', '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f4aa05d0278>, '_num_worker_replicas': 1, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_service': None, '_tf_random_seed': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd'}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_service': None, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f500c090390>, '_num_worker_replicas': 1, '_save_checkpoints_steps': 10000, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_log_step_count_steps': 100, '_tf_random_seed': None, '_task_type': 'worker', '_save_summary_steps': 100, '_master': '', '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_evaluation_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None}
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_task_id': 0, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': 10000, '_is_chief': True, '_global_id_in_cluster': 0, '_num_worker_replicas': 1, '_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f955c0102e8>, '_service': None, '_task_type': 'worker', '_master': '', '_log_step_count_steps': 100, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# }
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None, '_task_type': 'worker', '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff564f90320>, '_num_ps_replicas': 0, '_service': None, '_is_chief': True, '_tf_random_seed': None, '_save_checkpoints_steps': 10000, '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 100, '_save_summary_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_evaluation_master': ''}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_global_id_in_cluster': 0, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': None, '_evaluation_master': '', '_master': '', '_save_checkpoints_steps': 10000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7ff079090198>, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_worker_replicas': 1, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_service': None, '_save_summary_steps': 100, '_task_type': 'worker', '_log_step_count_steps': 100}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_master': '', '_save_checkpoints_steps': 10000, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3082c50358>, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_task_id': 0, '_service': None, '_is_chief': True, '_task_type': 'worker', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_num_worker_replicas': 1, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_log_step_count_steps': 100, '_service': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_task_type': 'worker', '_keep_checkpoint_max': 5, '_save_checkpoints_secs': None, '_is_chief': True, '_save_checkpoints_steps': 10000, '_master': '', '_tf_random_seed': None, '_task_id': 0, '_global_id_in_cluster': 0, '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8531c50320>, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_evaluation_master': '', '_num_worker_replicas': 1, '_num_ps_replicas': 0}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_steps': 10000, '_is_chief': True, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': None, '_evaluation_master': '', '_num_worker_replicas': 1, '_save_summary_steps': 100, '_service': None, '_tf_random_seed': None, '_task_id': 0, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f164ed50278>, '_master': '', '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_task_type': 'worker', '_keep_checkpoint_every_n_hours': 10000}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_tf_random_seed': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_num_worker_replicas': 1, '_service': None, '_keep_checkpoint_max': 5, '_task_id': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f29655d0198>, '_save_checkpoints_steps': 10000, '_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_evaluation_master': '', '_master': ''}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_log_step_count_steps': 100, '_service': None, '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_evaluation_master': '', '_save_checkpoints_secs': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b13d2eab-39ba-4218-8c76-d02562e001b1/outputs/Models', '_is_chief': True, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_keep_checkpoint_every_n_hours': 10000, '_num_worker_replicas': 1, '_tf_random_seed': None, '_save_summary_steps': 100, '_global_id_in_cluster': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9455552240>, '_keep_checkpoint_max': 5, '_master': '', '_task_type': 'worker', '_task_id': 0}
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_task_id': 0, '_global_id_in_cluster': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fcc6c4d0390>, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_log_step_count_steps': 100, '_service': None, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_is_chief': True, '_num_worker_replicas': 1, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_save_checkpoints_steps': 10000, '_save_checkpoints_secs': None, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_task_type': 'worker', '_evaluation_master': ''}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8b70452128>, '_num_worker_replicas': 1, '_task_id': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_ps_replicas': 0, '_master': '', '_tf_random_seed': None, '_save_summary_steps': 100, '_service': None, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_save_checkpoints_secs': None, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_task_type': 'worker'}
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_service': None, '_keep_checkpoint_max': 5, '_log_step_count_steps': 100, '_task_id': 0, '_is_chief': True, '_global_id_in_cluster': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f440ca50278>, '_tf_random_seed': None, '_evaluation_master': '', '_save_summary_steps': 100, '_task_type': 'worker', '_keep_checkpoint_every_n_hours': 10000, '_num_worker_replicas': 1, '_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_save_checkpoints_secs': None, '_save_checkpoints_steps': 10000}
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_service': None, '_global_id_in_cluster': 0, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_save_checkpoints_steps': 10000, '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_is_chief': True, '_num_worker_replicas': 1, '_task_type': 'worker', '_task_id': 0, '_keep_checkpoint_max': 5, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f28f2090278>}
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_task_type': 'worker', '_is_chief': True, '_evaluation_master': '', '_master': '', '_save_summary_steps': 100, '_num_worker_replicas': 1, '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_task_id': 0, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f250ecd22b0>, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_log_step_count_steps': 100}
# INFO:__main__:Rank: 1 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': 10000, '_service': None, '_task_type': 'worker', '_evaluation_master': '', '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f26ce5d22b0>, '_master': '', '_global_id_in_cluster': 0, '_is_chief': True, '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_save_checkpoints_secs': None, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_summary_steps': 100, '_task_id': 0, '_log_step_count_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# }
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_num_worker_replicas': 1, '_task_type': 'worker', '_master': '', '_log_step_count_steps': 100, '_service': None, '_evaluation_master': '', '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f9d3f8d0160>, '_save_checkpoints_steps': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_num_ps_replicas': 0, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_global_id_in_cluster': 0, '_is_chief': True, '_task_id': 0, '_save_summary_steps': 100}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_task_id': 0, '_save_checkpoints_steps': 10000, '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f345d950278>, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_evaluation_master': '', '_global_id_in_cluster': 0, '_task_type': 'worker', '_save_checkpoints_secs': None, '_service': None, '_is_chief': True, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_num_worker_replicas': 1, '_tf_random_seed': None}
# INFO:__main__:Rank: 0 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_num_worker_replicas': 1, '_tf_random_seed': None, '_evaluation_master': '', '_service': None, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_num_ps_replicas': 0, '_master': '', '_task_type': 'worker', '_save_checkpoints_steps': 10000, '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f2fc0390278>, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd'}
# INFO:__main__:Rank: 3 Cluster Size 24
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_service': None, '_global_id_in_cluster': 0, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_save_checkpoints_steps': 10000, '_tf_random_seed': None, '_task_id': 0, '_master': '', '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_evaluation_master': '', '_save_checkpoints_secs': None, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f032fc50358>, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd'}
# INFO:__main__:Rank: 2 Cluster Size 24
# INFO:__main__:Training...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
# INFO:tensorflow:loss = 6.012257, step = 401 (114.272 sec)
# INFO:tensorflow:global_step/sec: 0.870046
# INFO:tensorflow:global_step/sec: 0.870035
# INFO:tensorflow:global_step/sec: 0.870033
# INFO:tensorflow:global_step/sec: 0.870035
# INFO:tensorflow:global_step/sec: 0.870035
# INFO:tensorflow:global_step/sec: 0.870039
# INFO:tensorflow:global_step/sec: 0.870042
# INFO:tensorflow:global_step/sec: 0.870036
# INFO:tensorflow:global_step/sec: 0.870035
# INFO:tensorflow:global_step/sec: 0.87004
# INFO:tensorflow:global_step/sec: 0.870035
# INFO:tensorflow:global_step/sec: 0.870042
# INFO:tensorflow:global_step/sec: 0.870034
# INFO:tensorflow:global_step/sec: 0.870032
# INFO:tensorflow:global_step/sec: 0.870025
# INFO:tensorflow:global_step/sec: 0.870033
# INFO:tensorflow:global_step/sec: 0.870041
# INFO:tensorflow:global_step/sec: 0.870042
# INFO:tensorflow:global_step/sec: 0.870037
# INFO:tensorflow:step = 501, loss = 5.938624 (114.938 sec)
# INFO:tensorflow:loss = 6.049011, step = 501 (114.938 sec)
# INFO:tensorflow:loss = 6.0336933, step = 501 (114.937 sec)
# INFO:tensorflow:global_step/sec: 0.870032
# INFO:tensorflow:step = 501, loss = 6.2910385 (114.937 sec)
# INFO:tensorflow:step = 501, loss = 6.075911 (114.937 sec)
# INFO:tensorflow:loss = 6.027336, step = 501 (114.939 sec)
# INFO:tensorflow:step = 501, loss = 5.8907094 (114.938 sec)
# INFO:tensorflow:global_step/sec: 0.870032
# INFO:tensorflow:loss = 6.0741243, step = 501 (114.938 sec)
# INFO:tensorflow:step = 501, loss = 6.1812234 (114.937 sec)
# INFO:tensorflow:step = 501, loss = 6.086094 (114.935 sec)
# INFO:tensorflow:loss = 6.2063484, step = 501 (114.938 sec)
# INFO:tensorflow:global_step/sec: 0.870015
# INFO:tensorflow:step = 501, loss = 6.332283 (114.938 sec)
# INFO:tensorflow:loss = 6.2240973, step = 501 (114.938 sec)
# INFO:tensorflow:global_step/sec: 0.87003
# INFO:tensorflow:loss = 6.087799, step = 501 (114.938 sec)
# INFO:tensorflow:global_step/sec: 0.869995
# INFO:tensorflow:step = 501, loss = 6.077074 (114.941 sec)
# INFO:tensorflow:loss = 5.9457407, step = 501 (114.939 sec)
# INFO:tensorflow:loss = 6.1872926, step = 501 (114.938 sec)
# INFO:tensorflow:step = 501, loss = 5.8601933 (114.938 sec)
# INFO:tensorflow:loss = 5.702821, step = 501 (114.938 sec)
# INFO:tensorflow:loss = 6.0753555, step = 501 (114.943 sec)
# INFO:tensorflow:step = 501, loss = 6.436063 (115.116 sec)
# INFO:tensorflow:step = 501, loss = 6.133825 (114.939 sec)
# INFO:tensorflow:step = 501, loss = 6.1215067 (114.937 sec)
# INFO:tensorflow:step = 501, loss = 6.2380056 (114.939 sec)
# INFO:tensorflow:global_step/sec: 0.817352
# INFO:tensorflow:global_step/sec: 0.817339
# INFO:tensorflow:global_step/sec: 0.817346
# INFO:tensorflow:global_step/sec: 0.817352
# INFO:tensorflow:global_step/sec: 0.817337
# INFO:tensorflow:global_step/sec: 0.817353
# INFO:tensorflow:global_step/sec: 0.817338
# INFO:tensorflow:global_step/sec: 0.817341
# INFO:tensorflow:global_step/sec: 0.817341
# INFO:tensorflow:global_step/sec: 0.817349
# INFO:tensorflow:global_step/sec: 0.817338
# INFO:tensorflow:global_step/sec: 0.817362
# INFO:tensorflow:global_step/sec: 0.817339
# INFO:tensorflow:global_step/sec: 0.817374
# INFO:tensorflow:global_step/sec: 0.817355
# INFO:tensorflow:global_step/sec: 0.817349
# INFO:tensorflow:global_step/sec: 0.817339
# INFO:tensorflow:global_step/sec: 0.817352
# INFO:tensorflow:global_step/sec: 0.817338
# INFO:tensorflow:global_step/sec: 0.817339
# INFO:tensorflow:loss = 5.846056, step = 601 (122.348 sec)
# INFO:tensorflow:global_step/sec: 0.817354
# INFO:tensorflow:global_step/sec: 0.817338
# INFO:tensorflow:step = 601, loss = 5.818378 (122.345 sec)
# INFO:tensorflow:global_step/sec: 0.817338
# INFO:tensorflow:step = 601, loss = 5.915676 (122.348 sec)
# INFO:tensorflow:global_step/sec: 0.817326
# INFO:tensorflow:step = 601, loss = 5.9418187 (122.345 sec)
# INFO:tensorflow:loss = 6.1041603, step = 601 (122.348 sec)
# INFO:tensorflow:step = 601, loss = 6.0907035 (122.346 sec)
# INFO:tensorflow:step = 601, loss = 5.913093 (122.349 sec)
# INFO:tensorflow:loss = 6.0135646, step = 601 (122.347 sec)
# INFO:tensorflow:step = 601, loss = 6.059778 (122.347 sec)
# INFO:tensorflow:loss = 5.8921723, step = 601 (122.346 sec)
# INFO:tensorflow:loss = 6.207515, step = 601 (122.348 sec)
# INFO:tensorflow:step = 601, loss = 5.777266 (122.346 sec)
# INFO:tensorflow:step = 601, loss = 5.9191914 (122.348 sec)
# INFO:tensorflow:loss = 5.9286566, step = 601 (122.343 sec)
# INFO:tensorflow:step = 601, loss = 5.9962187 (122.351 sec)
# INFO:tensorflow:loss = 5.5721116, step = 601 (122.347 sec)
# INFO:tensorflow:loss = 5.89734, step = 601 (122.349 sec)
# INFO:tensorflow:step = 601, loss = 5.784737 (122.345 sec)
# INFO:tensorflow:loss = 5.8253164, step = 601 (122.348 sec)
# INFO:tensorflow:loss = 6.207152, step = 601 (122.348 sec)
# INFO:tensorflow:step = 601, loss = 5.8544517 (122.290 sec)
# INFO:tensorflow:step = 601, loss = 5.818223 (122.352 sec)
# INFO:tensorflow:step = 601, loss = 5.7515893 (122.348 sec)
# INFO:tensorflow:loss = 5.5961514, step = 601 (122.348 sec)
# INFO:tensorflow:global_step/sec: 0.829912
# INFO:tensorflow:global_step/sec: 0.829912
# INFO:tensorflow:global_step/sec: 0.829903
# INFO:tensorflow:global_step/sec: 0.829912
# INFO:tensorflow:global_step/sec: 0.8299
# INFO:tensorflow:global_step/sec: 0.829908
# INFO:tensorflow:global_step/sec: 0.829906
# INFO:tensorflow:global_step/sec: 0.829913
# INFO:tensorflow:step = 701, loss = 5.948208 (120.496 sec)
# INFO:tensorflow:global_step/sec: 0.829908
# INFO:tensorflow:global_step/sec: 0.829899
# INFO:tensorflow:loss = 6.0778017, step = 701 (120.495 sec)
# INFO:tensorflow:global_step/sec: 0.829909
# INFO:tensorflow:global_step/sec: 0.829902
# INFO:tensorflow:global_step/sec: 0.829899
# INFO:tensorflow:global_step/sec: 0.829909
# INFO:tensorflow:global_step/sec: 0.829892
# INFO:tensorflow:step = 701, loss = 5.5410414 (120.495 sec)
# INFO:tensorflow:global_step/sec: 0.829908
# INFO:tensorflow:loss = 5.785157, step = 701 (120.495 sec)
# INFO:tensorflow:global_step/sec: 0.829898
# INFO:tensorflow:global_step/sec: 0.82991
# INFO:tensorflow:step = 701, loss = 5.8443036 (120.496 sec)
# INFO:tensorflow:global_step/sec: 0.829896
# INFO:tensorflow:step = 701, loss = 5.433482 (120.496 sec)
# INFO:tensorflow:global_step/sec: 0.829922
# INFO:tensorflow:step = 701, loss = 5.957513 (120.491 sec)
# INFO:tensorflow:loss = 6.171092, step = 701 (120.495 sec)
# INFO:tensorflow:step = 701, loss = 5.889514 (120.497 sec)
# INFO:tensorflow:step = 701, loss = 5.7669134 (120.497 sec)
# INFO:tensorflow:loss = 5.7561245, step = 701 (120.495 sec)
# INFO:tensorflow:step = 701, loss = 5.9611006 (120.493 sec)
# INFO:tensorflow:loss = 6.0849104, step = 701 (120.497 sec)
# INFO:tensorflow:loss = 5.7567215, step = 701 (120.495 sec)
# INFO:tensorflow:step = 701, loss = 5.719269 (120.498 sec)
# INFO:tensorflow:global_step/sec: 0.829889
# INFO:tensorflow:loss = 5.720313, step = 701 (120.495 sec)
# INFO:tensorflow:step = 701, loss = 5.695036 (120.492 sec)
# INFO:tensorflow:global_step/sec: 0.829825
# INFO:tensorflow:loss = 5.847418, step = 701 (120.495 sec)
# INFO:tensorflow:global_step/sec: 0.829852
# INFO:tensorflow:loss = 5.850218, step = 701 (120.498 sec)
# INFO:tensorflow:global_step/sec: 0.829863
# INFO:tensorflow:step = 701, loss = 5.6928596 (120.673 sec)
# INFO:tensorflow:loss = 5.890271, step = 701 (120.508 sec)
# INFO:tensorflow:step = 701, loss = 6.387652 (120.495 sec)
# INFO:tensorflow:step = 701, loss = 5.751934 (120.503 sec)
# INFO:tensorflow:loss = 5.3256874, step = 701 (120.502 sec)
# INFO:tensorflow:global_step/sec: 0.863214
# INFO:tensorflow:global_step/sec: 0.863218
# INFO:tensorflow:global_step/sec: 0.863173
# INFO:tensorflow:loss = 5.8457937, step = 801 (115.846 sec)
# INFO:tensorflow:global_step/sec: 0.863167
# INFO:tensorflow:global_step/sec: 0.863232
# INFO:tensorflow:global_step/sec: 0.863256
# INFO:tensorflow:global_step/sec: 0.863207
# INFO:tensorflow:global_step/sec: 0.863174
# INFO:tensorflow:global_step/sec: 0.863203
# INFO:tensorflow:global_step/sec: 0.863218
# INFO:tensorflow:global_step/sec: 0.86322
# INFO:tensorflow:global_step/sec: 0.863206
# INFO:tensorflow:step = 801, loss = 5.8996286 (115.549 sec)
# INFO:tensorflow:global_step/sec: 0.863248
# INFO:tensorflow:global_step/sec: 0.863202
# INFO:tensorflow:step = 801, loss = 5.6030836 (115.853 sec)
# INFO:tensorflow:global_step/sec: 0.863201
# INFO:tensorflow:global_step/sec: 0.863205
# INFO:tensorflow:loss = 5.3947325, step = 801 (115.847 sec)
# INFO:tensorflow:step = 801, loss = 5.3191633 (115.851 sec)
# INFO:tensorflow:loss = 5.5323715, step = 801 (115.848 sec)
# INFO:tensorflow:step = 801, loss = 5.330121 (115.846 sec)
# INFO:tensorflow:loss = 5.5209675, step = 801 (115.844 sec)
# INFO:tensorflow:loss = 5.9658546, step = 801 (115.841 sec)
# INFO:tensorflow:global_step/sec: 0.863196
# INFO:tensorflow:loss = 5.784666, step = 801 (115.851 sec)
# INFO:tensorflow:global_step/sec: 0.863185
# INFO:tensorflow:global_step/sec: 0.863156
# INFO:tensorflow:step = 801, loss = 5.4942236 (115.845 sec)
# INFO:tensorflow:loss = 5.6349416, step = 801 (115.847 sec)
# INFO:tensorflow:step = 801, loss = 5.5549126 (115.849 sec)
# INFO:tensorflow:loss = 5.4860363, step = 801 (115.841 sec)
# INFO:tensorflow:step = 801, loss = 5.5542107 (115.848 sec)
# INFO:tensorflow:step = 801, loss = 5.6128445 (115.854 sec)
# INFO:tensorflow:loss = 5.3120546, step = 801 (115.848 sec)
# INFO:tensorflow:loss = 5.2957077, step = 801 (115.848 sec)
# INFO:tensorflow:global_step/sec: 0.863181
# INFO:tensorflow:global_step/sec: 0.863128
# INFO:tensorflow:loss = 5.5417423, step = 801 (115.850 sec)
# INFO:tensorflow:global_step/sec: 0.86312
# INFO:tensorflow:global_step/sec: 0.863183
# INFO:tensorflow:global_step/sec: 0.863176
# INFO:tensorflow:step = 801, loss = 5.760751 (115.850 sec)
# INFO:tensorflow:step = 801, loss = 5.913167 (115.858 sec)
# INFO:tensorflow:step = 801, loss = 6.0295997 (115.859 sec)
# INFO:tensorflow:step = 801, loss = 5.6736245 (115.850 sec)
# INFO:tensorflow:step = 801, loss = 5.1045017 (115.851 sec)
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b13d2eab-39ba-4218-8c76-d02562e001b1/outputs/Models/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 834 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.8806143.
# INFO:__main__:Training took 1328.134 seconds
# INFO:tensorflow:Loss for final step: 5.462554.
# INFO:__main__:Training took 1328.705 seconds
# INFO:tensorflow:Loss for final step: 5.813815.
# INFO:__main__:Training took 1328.755 seconds
# INFO:tensorflow:Loss for final step: 5.8270245.
# INFO:__main__:Training took 1328.647 seconds
# INFO:tensorflow:Loss for final step: 5.379318.
# INFO:__main__:Training took 1328.865 seconds
# INFO:tensorflow:Loss for final step: 5.7462025.
# INFO:__main__:Training took 1328.894 seconds
# INFO:tensorflow:Loss for final step: 5.419549.
# INFO:__main__:Training took 1330.402 seconds
# INFO:tensorflow:Loss for final step: 5.7726736.
# INFO:__main__:Training took 1330.587 seconds
# INFO:tensorflow:Loss for final step: 5.6847973.
# INFO:__main__:Training took 1330.810 seconds
# INFO:tensorflow:Loss for final step: 5.485409.
# INFO:__main__:Training took 1330.585 seconds
# INFO:tensorflow:Loss for final step: 5.7434034.
# INFO:__main__:Training took 1331.068 seconds
# INFO:tensorflow:Loss for final step: 5.651478.
# INFO:__main__:Training took 1331.031 seconds
# INFO:tensorflow:Loss for final step: 5.553027.
# INFO:__main__:Training took 1332.371 seconds
# INFO:tensorflow:Loss for final step: 5.8935.
# INFO:__main__:Training took 1332.695 seconds
# INFO:tensorflow:Loss for final step: 5.701312.
# INFO:__main__:Training took 1332.568 seconds
# INFO:tensorflow:Loss for final step: 5.42334.
# INFO:__main__:Training took 1332.710 seconds
# INFO:tensorflow:Loss for final step: 5.7054863.
# INFO:tensorflow:Loss for final step: 5.637905.
# INFO:__main__:Training took 1332.752 seconds
# INFO:__main__:Training took 1332.599 seconds
# INFO:tensorflow:Loss for final step: 5.3634796.
# INFO:__main__:Training took 1334.395 seconds
# INFO:tensorflow:Loss for final step: 5.409927.
# INFO:__main__:Training took 1334.636 seconds
# INFO:tensorflow:Loss for final step: 5.6152263.
# INFO:__main__:Training took 1334.737 seconds
# INFO:tensorflow:Loss for final step: 5.6620536.
# INFO:__main__:Training took 1334.462 seconds
# INFO:tensorflow:Loss for final step: 5.306897.
# INFO:__main__:Training took 1334.791 seconds
# INFO:tensorflow:Loss for final step: 5.5279346.
# INFO:__main__:Training took 1344.411 seconds
# INFO:__main__:Testing...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-14-13:44:43
# INFO:tensorflow:Graph was finalized.
# 2018-05-14 13:44:44.282365: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-14 13:44:44.297074: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 6867 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0672:00:00.0, compute capability: 7.0)
# INFO:tensorflow:Restoring parameters from /mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b13d2eab-39ba-4218-8c76-d02562e001b1/outputs/Models/model.ckpt-834
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-14-13:47:10
# INFO:tensorflow:Saving dict for global step 834: accuracy = 0.047194693, global_step = 834, loss = 5.62342
# INFO:__main__:Testing took 150.205 seconds
# ^C

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stdout.txt

# %%
# !az batchai job delete --name horovod_benchmark -y
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
#  - Finished ..

# %%
# !az configure --defaults group=''
# !az configure --defaults location=''

# %%
# !az batchai cluster delete --name nc24r -g $GROUP_NAME -y
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
#  - Finished ..

# %%
# !az batchai file-server delete -n $NFS_NAME -y -g $GROUP_NAME
# Out:
# Using default 'batch6c03bc15rg' for arg resource_group_name
#  - Finished ..

# %%
# !az group delete --name $GROUP_NAME -y
# Out:
# Using default 'batch6c03bc15rg' for arg resource_group_name
#  - Finished ..
