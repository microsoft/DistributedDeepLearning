# %%
# !az login -o table
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code BSHR6F4TQ to authenticate.
# CloudName    Name                           State    TenantId                              IsDefault
# -----------  -----------------------------  -------  ------------------------------------  -----------
# AzureCloud   Boston DS Dev                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Azure Internal - London        Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Danielle Internal         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47  True
# AzureCloud   Visual Studio Enterprise       Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Boston Engineering             Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   ADLTrainingMS                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   UST Container Registration     Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyExt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Ads Eng Big Data Subscription  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling Preview         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling development     Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   AzureML Client PROD            Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   R portal - Production          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyInt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Project Vienna Demo 1          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   ASutton Subscription           Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Solution Template Testing      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Ilan                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Marketing Automation           Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47

# %%
# !az provider register -n Microsoft.BatchAI
# !az provider register -n Microsoft.Batch

# %%
# !az account list -o table
# Out:
# Name                           CloudName    SubscriptionId                        State    IsDefault
# -----------------------------  -----------  ------------------------------------  -------  -----------
# Boston DS Dev                  AzureCloud   0ca618d2-22a8-413a-96d0-0f1b531129c3  Enabled
# Azure Internal - London        AzureCloud   1ba81249-8edd-4619-a486-3d28a2176aad  Enabled
# Team Danielle Internal         AzureCloud   edf507a2-6235-46c5-b560-fd463ba2e771  Enabled  True
# Visual Studio Enterprise       AzureCloud   fb11e9eb-22e1-4347-8d0a-84ef60157664  Enabled
# Boston Engineering             AzureCloud   bc4170f0-cc6e-49d2-ba65-bc00a7a4df6b  Enabled
# ADLTrainingMS                  AzureCloud   ace74b35-b0de-428b-a1d9-55459d7a6e30  Enabled
# PhillyExt                      AzureCloud   a20c82c7-4497-4d44-952a-3105f790e26b  Enabled
# Ads Eng Big Data Subscription  AzureCloud   d4231148-f093-4473-85de-8c4d19247495  Enabled
# Data Wrangling Preview         AzureCloud   215613ac-9dfb-488c-be46-c387e999b127  Enabled
# Data Wrangling development     AzureCloud   35f16a99-532a-4a47-9e93-00305f6c40f2  Enabled
# AzureML Client PROD            AzureCloud   4a0f8d7f-c197-476b-95e1-fafcd77f12e4  Enabled
# R portal - Production          AzureCloud   2569dcd9-a995-4b78-ae22-58a1015fd0f7  Enabled
# PhillyInt                      AzureCloud   d50e5f6b-6c27-4ab1-8587-3d85cef6426e  Enabled
# Solution Template Testing      AzureCloud   3bcfa59c-82a0-44f9-ac08-b3479370bace  Enabled
# Team Ilan                      AzureCloud   ff18d7a8-962a-406c-858f-49acd23d6c01  Enabled
# Marketing Automation           AzureCloud   03909a66-bef8-4d52-8e9a-a346604e0902  Enabled
# Project Vienna Demo 1          AzureCloud   75f78a03-482f-4fd8-8c71-5ddc08f92726  Enabled

# %%
# !az account set -s "<YOURTEAM>"

# %%
# !az --version
# Out:
# azure-cli (2.0.24)
#
# acr (2.0.18)
# acs (2.0.23)
# advisor (0.1.1)
# appservice (0.1.23)
# backup (1.0.4)
# batch (3.1.8)
# batchai (0.1.4)
# billing (0.1.7)
# cdn (0.0.11)
# cloud (2.0.11)
# cognitiveservices (0.1.10)
# command-modules-nspkg (2.0.1)
# configure (2.0.13)
# consumption (0.2.1)
# container (0.1.16)
# core (2.0.24)
# cosmosdb (0.1.16)
# dla (0.0.16)
# dls (0.0.19)
# eventgrid (0.1.7)
# extension (0.0.7)
# feedback (2.0.7)
# find (0.2.8)
# interactive (0.3.12)
# iot (0.1.16)
# keyvault (2.0.16)
# lab (0.0.14)
# monitor (0.0.14)
# network (2.0.20)
# nspkg (3.0.1)
# profile (2.0.17)
# rdbms (0.0.10)
# redis (0.2.11)
# reservations (0.1.1)
# resource (2.0.20)
# role (2.0.16)
# servicefabric (0.0.8)
# sql (2.0.18)
# storage (2.0.22)
# vm (2.0.23)
#
# Extensions:
# azure-cli-machinelearning (0.0.97)
#
# Python location '/opt/az/bin/python3'
# Extensions directory '/home/mat/.azure/cliextensions'
#
# Python (Linux) 3.6.1 (default, Jan  5 2018, 21:18:08)
# [GCC 4.8.4]
#
# Legal docs and information: aka.ms/AzureCliLegal

# %%
import os
import uuid
import random
import json

def write_json_to_file(json_dict, filename):
    """ Simple function to write JSON dictionaries to files
    """
    with open(filename, 'w') as outfile:
        json.dump(json_dict, outfile)

LOCATION = 'eastus' # We are setting everything up in East US
                    # Be aware that you need to set things up in a region that has GPU VMs (N-Series)

short_uuid = str(uuid.uuid4())[:8]
GROUP_NAME = "batch{uuid}rg".format(uuid=short_uuid)
STORAGE_ACCOUNT_NAME = "batch{uuid}st".format(uuid=short_uuid)
CONTAINER_NAME = "batch{uuid}container".format(uuid=short_uuid)
FILESHARE_NAME = "batch{uuid}share".format(uuid=short_uuid)
NFS_NAME="batch{uuid}nfs".format(uuid=short_uuid)

# %%
# !az group create -n $GROUP_NAME -o table -l $LOCATION
# Out:
# Location    Name
# ----------  ---------------
# eastus      batchfcab5890rg

# %%
json_data = !az storage account create -l $LOCATION -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME --sku Standard_LRS
print('Storage account {} provisioning state: {}'.format(STORAGE_ACCOUNT_NAME, json.loads(''.join(json_data))['provisioningState']))
# Out:
# Storage account batchfcab5890st provisioning state: Succeeded

# %%
json_data = !az storage account keys list -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME
storage_account_key = json.loads(''.join([i for i in json_data if 'WARNING' not in i]))[0]['value']

# %%
# !az storage container create --account-name $STORAGE_ACCOUNT_NAME \
--account-key $storage_account_key --name $CONTAINER_NAME
# Out:
# {
#   "created": true
# }

# %%
# !az storage share create --account-name $STORAGE_ACCOUNT_NAME \
--account-key $storage_account_key --name $FILESHARE_NAME
# Out:
# {
#   "created": true
# }

# %%
# !az storage directory create --share-name $FILESHARE_NAME  --name scripts \
--account-name $STORAGE_ACCOUNT_NAME --account-key $storage_account_key
# Out:
# {
#   "created": true
# }

# %%
# !az configure --defaults location=$LOCATION

# %%
# !az configure --defaults group=$GROUP_NAME

# %%
# %env AZURE_STORAGE_ACCOUNT $STORAGE_ACCOUNT_NAME
# Out:
# env: AZURE_STORAGE_ACCOUNT=batchfcab5890st

# %%
# %env AZURE_STORAGE_KEY=$storage_account_key
# Out:
# env: AZURE_STORAGE_KEY=qTUeM/dh+vIhiKcrYx3EkvJKEOACztR2D7GAxE/5bRXnkxdU1T3e1JyYmbL4Rr43AMt6NMYW3OXPrg0iiyLk1g==

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'validation')

# %%
# !azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation \
        --source-key 'owUPSqTbwAigV54BHTr8oYABEha8xi/VsA4HD06GboDgOb3pf6OFgtw/tlKYv/AlkgSIBkxqoA28hnkIeo4NFg==' \
        --destination  $destination_url \
        --dest-key $storage_account_key --quiet --recursive
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 129.578 KB; Average Speed:9.37 KB/s.                      Finished: 1 file(s), 129.578 KB; Average Speed:8.17 KB/s.                      Finished: 1 file(s), 326.544 KB; Average Speed:10.81 KB/s.                     Finished: 7 file(s), 1.129 MB; Average Speed:35.87 KB/s.                       Finished: 17 file(s), 2.165 MB; Average Speed:64.67 KB/s.                      Finished: 25 file(s), 3.153 MB; Average Speed:88.86 KB/s.                      Finished: 33 file(s), 4.221 MB; Average Speed:112.62 KB/s.                     Finished: 40 file(s), 5.188 MB; Average Speed:131.41 KB/s.                     Finished: 50 file(s), 6.278 MB; Average Speed:151.34 KB/s.                     Finished: 59 file(s), 7.241 MB; Average Speed:166.53 KB/s.                     Finished: 66 file(s), 8.148 MB; Average Speed:179.15 KB/s.                     Finished: 77 file(s), 9.197 MB; Average Speed:193.68 KB/s.                     Finished: 84 file(s), 10.149 MB; Average Speed:205.11 KB/s.                    Finished: 231 file(s), 27.935 MB; Average Speed:542.62 KB/s.                   Finished: 413 file(s), 51.583 MB; Average Speed:964.5 KB/s.                    Finished: 594 file(s), 76.163 MB; Average Speed:1.34 MB/s.                     Finished: 792 file(s), 101.992 MB; Average Speed:1.73 MB/s.                    Finished: 990 file(s), 126.493 MB; Average Speed:2.08 MB/s.                    Finished: 1188 file(s), 151.76 MB; Average Speed:2.41 MB/s.                    Finished: 1382 file(s), 176.513 MB; Average Speed:2.72 MB/s.                   Finished: 1580 file(s), 201.622 MB; Average Speed:3.01 MB/s.                   Finished: 1777 file(s), 227.16 MB; Average Speed:3.29 MB/s.                    Finished: 1974 file(s), 250.988 MB; Average Speed:3.53 MB/s.                   Finished: 2179 file(s), 276.818 MB; Average Speed:3.78 MB/s.                   Finished: 2343 file(s), 298.577 MB; Average Speed:3.97 MB/s.                   Finished: 2515 file(s), 319.964 MB; Average Speed:4.14 MB/s.                   Finished: 2696 file(s), 341.854 MB; Average Speed:4.31 MB/s.                   Finished: 2864 file(s), 363.029 MB; Average Speed:4.46 MB/s.                   Finished: 3028 file(s), 385.103 MB; Average Speed:4.62 MB/s.                   Finished: 3210 file(s), 405.841 MB; Average Speed:4.75 MB/s.                   Finished: 3387 file(s), 426.997 MB; Average Speed:4.88 MB/s.                   Finished: 3573 file(s), 449.337 MB; Average Speed:5.02 MB/s.                   Finished: 3757 file(s), 472.292 MB; Average Speed:5.15 MB/s.                   Finished: 3957 file(s), 495.767 MB; Average Speed:5.29 MB/s.                   Finished: 4139 file(s), 517.565 MB; Average Speed:5.41 MB/s.                   Finished: 4324 file(s), 540.839 MB; Average Speed:5.53 MB/s.                   Finished: 4493 file(s), 563.779 MB; Average Speed:5.65 MB/s.                   Finished: 4686 file(s), 586.973 MB; Average Speed:5.76 MB/s.                   Finished: 4861 file(s), 609.401 MB; Average Speed:5.86 MB/s.                   Finished: 5040 file(s), 633.498 MB; Average Speed:5.98 MB/s.                   Finished: 5225 file(s), 656.436 MB; Average Speed:6.08 MB/s.                   Finished: 5412 file(s), 679.238 MB; Average Speed:6.17 MB/s.                   Finished: 5596 file(s), 701.226 MB; Average Speed:6.25 MB/s.                   Finished: 5830 file(s), 728.765 MB; Average Speed:6.38 MB/s.                   Finished: 6029 file(s), 753.621 MB; Average Speed:6.49 MB/s.                   Finished: 6229 file(s), 779.032 MB; Average Speed:6.59 MB/s.                   Finished: 6420 file(s), 803.783 MB; Average Speed ...
# Finished: 13164 file(s), 1.615 GB; Average Speed:8.35 MB/s.                    Finished: 13365 file(s), 1.638 GB; Average Speed:8.38 MB/s.                    Finished: 13538 file(s), 1.662 GB; Average Speed:8.41 MB/s.                    Finished: 13700 file(s), 1.683 GB; Average Speed:8.44 MB/s.                    Finished: 13865 file(s), 1.703 GB; Average Speed:8.45 MB/s.                    Finished: 14016 file(s), 1.723 GB; Average Speed:8.47 MB/s.                    Finished: 14140 file(s), 1.742 GB; Average Speed:8.48 MB/s.                    Finished: 14287 file(s), 1.762 GB; Average Speed:8.49 MB/s.                    Finished: 14422 file(s), 1.781 GB; Average Speed:8.5 MB/s.                     Finished: 14591 file(s), 1.8 GB; Average Speed:8.51 MB/s.                      Finished: 14735 file(s), 1.818 GB; Average Speed:8.52 MB/s.                    Finished: 14876 file(s), 1.837 GB; Average Speed:8.53 MB/s.                    Finished: 15028 file(s), 1.858 GB; Average Speed:8.54 MB/s.                    Finished: 15189 file(s), 1.876 GB; Average Speed:8.55 MB/s.                    Finished: 15354 file(s), 1.896 GB; Average Speed:8.56 MB/s.                    Finished: 15523 file(s), 1.918 GB; Average Speed:8.58 MB/s.                    Finished: 15702 file(s), 1.941 GB; Average Speed:8.61 MB/s.                    Finished: 15885 file(s), 1.964 GB; Average Speed:8.63 MB/s.                    Finished: 16084 file(s), 1.986 GB; Average Speed:8.66 MB/s.                    Finished: 16270 file(s), 2.008 GB; Average Speed:8.68 MB/s.                    Finished: 16444 file(s), 2.032 GB; Average Speed:8.7 MB/s.                     Finished: 16626 file(s), 2.055 GB; Average Speed:8.73 MB/s.                    Finished: 16798 file(s), 2.077 GB; Average Speed:8.74 MB/s.                    Finished: 17002 file(s), 2.1 GB; Average Speed:8.77 MB/s.                      Finished: 17189 file(s), 2.123 GB; Average Speed:8.79 MB/s.                    Finished: 17372 file(s), 2.147 GB; Average Speed:8.82 MB/s.                    Finished: 17550 file(s), 2.17 GB; Average Speed:8.84 MB/s.                     Finished: 17690 file(s), 2.187 GB; Average Speed:8.84 MB/s.                    Finished: 17832 file(s), 2.207 GB; Average Speed:8.85 MB/s.                    Finished: 17944 file(s), 2.227 GB; Average Speed:8.85 MB/s.                    Finished: 18107 file(s), 2.247 GB; Average Speed:8.86 MB/s.                    Finished: 18246 file(s), 2.266 GB; Average Speed:8.87 MB/s.                    Finished: 18393 file(s), 2.285 GB; Average Speed:8.88 MB/s.                    Finished: 18542 file(s), 2.304 GB; Average Speed:8.88 MB/s.                    Finished: 18695 file(s), 2.325 GB; Average Speed:8.89 MB/s.                    Finished: 18862 file(s), 2.343 GB; Average Speed:8.89 MB/s.                    Finished: 19008 file(s), 2.363 GB; Average Speed:8.9 MB/s.                     Finished: 19164 file(s), 2.382 GB; Average Speed:8.9 MB/s.                     Finished: 19331 file(s), 2.403 GB; Average Speed:8.92 MB/s.                    Finished: 19492 file(s), 2.425 GB; Average Speed:8.93 MB/s.                    Finished: 19667 file(s), 2.447 GB; Average Speed:8.95 MB/s.                    Finished: 19835 file(s), 2.468 GB; Average Speed:8.96 MB/s.                    Finished: 20007 file(s), 2.49 GB; Average Speed:8.97 MB/s.                     Finished: 20194 file(s), 2.512 GB; Average Speed:8.99 MB/s.                    Finished: 20395 file(s), 2.535 GB; Average Speed:9 MB/s.                       Finished: 20571 file(s), 2.559 GB; Average Speed:9.03 MB/s.                    Finished: 20755 file(s), 2.582 GB; Average Speed:9.05 MB/s.                    Finished: 20958 file(s), 2.606 GB; Average Speed:9.07 MB/s.                    Finished: 21152 file(s), 2.63 GB; Average Speed:9.09 MB/s.                     Finished: 21331 file(s), 2.653 GB; Average Speed:9.1 MB/s.                     Finished: 21536 file(s), 2.676 GB; Average Speed:9 ...
# Finished: 28412 file(s), 3.533 GB; Average Speed:9.51 MB/s.                    Finished: 28541 file(s), 3.554 GB; Average Speed:9.52 MB/s.                    Finished: 28712 file(s), 3.575 GB; Average Speed:9.52 MB/s.                    Finished: 28877 file(s), 3.595 GB; Average Speed:9.52 MB/s.                    Finished: 29046 file(s), 3.616 GB; Average Speed:9.53 MB/s.                    Finished: 29211 file(s), 3.636 GB; Average Speed:9.53 MB/s.                    Finished: 29368 file(s), 3.656 GB; Average Speed:9.53 MB/s.                    Finished: 29534 file(s), 3.676 GB; Average Speed:9.54 MB/s.                    Finished: 29704 file(s), 3.696 GB; Average Speed:9.54 MB/s.                    Finished: 29837 file(s), 3.717 GB; Average Speed:9.54 MB/s.                    Finished: 29996 file(s), 3.737 GB; Average Speed:9.54 MB/s.                    Finished: 30149 file(s), 3.756 GB; Average Speed:9.55 MB/s.                    Finished: 30326 file(s), 3.777 GB; Average Speed:9.55 MB/s.                    Finished: 30522 file(s), 3.801 GB; Average Speed:9.56 MB/s.                    Finished: 30725 file(s), 3.825 GB; Average Speed:9.57 MB/s.                    Finished: 30917 file(s), 3.85 GB; Average Speed:9.59 MB/s.                     Finished: 31124 file(s), 3.875 GB; Average Speed:9.6 MB/s.                     Finished: 31321 file(s), 3.898 GB; Average Speed:9.61 MB/s.                    Finished: 31519 file(s), 3.922 GB; Average Speed:9.62 MB/s.                    Finished: 31705 file(s), 3.944 GB; Average Speed:9.63 MB/s.                    Finished: 31905 file(s), 3.968 GB; Average Speed:9.64 MB/s.                    Finished: 32102 file(s), 3.99 GB; Average Speed:9.65 MB/s.                     Finished: 32304 file(s), 4.014 GB; Average Speed:9.66 MB/s.                    Finished: 32481 file(s), 4.036 GB; Average Speed:9.67 MB/s.                    Finished: 32669 file(s), 4.06 GB; Average Speed:9.68 MB/s.                     Finished: 32845 file(s), 4.082 GB; Average Speed:9.68 MB/s.                    Finished: 33025 file(s), 4.105 GB; Average Speed:9.69 MB/s.                    Finished: 33184 file(s), 4.126 GB; Average Speed:9.7 MB/s.                     Finished: 33350 file(s), 4.146 GB; Average Speed:9.7 MB/s.                     Finished: 33517 file(s), 4.167 GB; Average Speed:9.7 MB/s.                     Finished: 33679 file(s), 4.187 GB; Average Speed:9.7 MB/s.                     Finished: 33803 file(s), 4.209 GB; Average Speed:9.71 MB/s.                    Finished: 33982 file(s), 4.231 GB; Average Speed:9.72 MB/s.                    Finished: 34174 file(s), 4.255 GB; Average Speed:9.73 MB/s.                    Finished: 34374 file(s), 4.279 GB; Average Speed:9.74 MB/s.                    Finished: 34519 file(s), 4.302 GB; Average Speed:9.74 MB/s.                    Finished: 34710 file(s), 4.327 GB; Average Speed:9.76 MB/s.                    Finished: 34910 file(s), 4.351 GB; Average Speed:9.77 MB/s.                    Finished: 35111 file(s), 4.375 GB; Average Speed:9.78 MB/s.                    Finished: 35304 file(s), 4.4 GB; Average Speed:9.79 MB/s.                      Finished: 35498 file(s), 4.424 GB; Average Speed:9.8 MB/s.                     Finished: 35694 file(s), 4.449 GB; Average Speed:9.81 MB/s.                    Finished: 35874 file(s), 4.473 GB; Average Speed:9.82 MB/s.                    Finished: 36070 file(s), 4.497 GB; Average Speed:9.83 MB/s.                    Finished: 36274 file(s), 4.521 GB; Average Speed:9.84 MB/s.                    Finished: 36466 file(s), 4.543 GB; Average Speed:9.85 MB/s.                    Finished: 36661 file(s), 4.567 GB; Average Speed:9.85 MB/s.                    Finished: 36860 file(s), 4.591 GB; Average Speed:9.86 MB/s.                    Finished: 37037 file(s), 4.614 GB; Average Speed:9.87 MB/s.                    Finished: 37222 file(s), 4.638 GB; Average Speed:9.88 MB/s.                    Finished: 37400 file(s), 4.661 GB; Average Speed:9 ...
# Finished: 44189 file(s), 5.515 GB; Average Speed:10.07 MB/s.                   Finished: 44369 file(s), 5.537 GB; Average Speed:10.08 MB/s.                   Finished: 44575 file(s), 5.561 GB; Average Speed:10.08 MB/s.                   Finished: 44755 file(s), 5.583 GB; Average Speed:10.09 MB/s.                   Finished: 44919 file(s), 5.603 GB; Average Speed:10.09 MB/s.                   Finished: 45106 file(s), 5.625 GB; Average Speed:10.09 MB/s.                   Finished: 45270 file(s), 5.648 GB; Average Speed:10.09 MB/s.                   Finished: 45461 file(s), 5.672 GB; Average Speed:10.1 MB/s.                    Finished: 45661 file(s), 5.695 GB; Average Speed:10.11 MB/s.                   Finished: 45861 file(s), 5.72 GB; Average Speed:10.11 MB/s.                    Finished: 46017 file(s), 5.741 GB; Average Speed:10.12 MB/s.                   Finished: 46201 file(s), 5.764 GB; Average Speed:10.12 MB/s.                   Finished: 46391 file(s), 5.787 GB; Average Speed:10.13 MB/s.                   Finished: 46568 file(s), 5.813 GB; Average Speed:10.14 MB/s.                   Finished: 46740 file(s), 5.834 GB; Average Speed:10.14 MB/s.                   Finished: 46923 file(s), 5.857 GB; Average Speed:10.14 MB/s.                   Finished: 47073 file(s), 5.881 GB; Average Speed:10.15 MB/s.                   Finished: 47286 file(s), 5.905 GB; Average Speed:10.16 MB/s.                   Finished: 47494 file(s), 5.929 GB; Average Speed:10.16 MB/s.                   Finished: 47695 file(s), 5.954 GB; Average Speed:10.17 MB/s.                   Finished: 47884 file(s), 5.979 GB; Average Speed:10.18 MB/s.                   Finished: 48078 file(s), 6.004 GB; Average Speed:10.18 MB/s.                   Finished: 48259 file(s), 6.026 GB; Average Speed:10.19 MB/s.                   Finished: 48441 file(s), 6.05 GB; Average Speed:10.19 MB/s.                    Finished: 48629 file(s), 6.076 GB; Average Speed:10.2 MB/s.                    Finished: 48838 file(s), 6.101 GB; Average Speed:10.21 MB/s.                   Finished: 49028 file(s), 6.127 GB; Average Speed:10.22 MB/s.                   Finished: 49228 file(s), 6.152 GB; Average Speed:10.23 MB/s.                   Finished: 49439 file(s), 6.176 GB; Average Speed:10.23 MB/s.                   Finished: 49655 file(s), 6.202 GB; Average Speed:10.24 MB/s.                   Finished: 49853 file(s), 6.227 GB; Average Speed:10.25 MB/s.                   Finished: 49998 file(s), 6.246 GB; Average Speed:10.25 MB/s.                   Finished: 49999 file(s), 6.246 GB; Average Speed:10.21 MB/s.                   Finished: 50000 file(s), 6.246 GB; Average Speed:10.18 MB/s.                                                                                                  Finished 50000 of total 50000 file(s).
#                                                                                [2018/05/20 12:07:12] Transfer summary:
# -----------------
# Total files transferred: 50000
# Transfer successfully:   50000
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.00:10:32

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'train')

# %%
# !azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train \
        --source-key 'owUPSqTbwAigV54BHTr8oYABEha8xi/VsA4HD06GboDgOb3pf6OFgtw/tlKYv/AlkgSIBkxqoA28hnkIeo4NFg==' \
        --destination  $destination_url \
        --dest-key $storage_account_key --quiet --recursive --exclude-older
# Out:
# =                                                                               Finished 0 of total 0 file(s).
#                                                                                [2018/05/20 13:37:56] Transfer summary:
# -----------------
# Total files transferred: 0
# Transfer successfully:   0
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.01:25:20

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'train.csv')

# %%
# !azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train.csv \
        --source-key 'owUPSqTbwAigV54BHTr8oYABEha8xi/VsA4HD06GboDgOb3pf6OFgtw/tlKYv/AlkgSIBkxqoA28hnkIeo4NFg==' \
        --destination  $destination_url \
        --dest-key $storage_account_key --quiet
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 62.739 MB; Average Speed:2.05 MB/s.                       Finished: 1 file(s), 62.739 MB; Average Speed:1.92 MB/s.                                                                                                      Finished 1 of total 1 file(s).
#                                                                                [2018/05/20 14:59:36] Transfer summary:
# -----------------
# Total files transferred: 1
# Transfer successfully:   1
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.00:00:36

# %%
destination_url = "https://{}.blob.core.windows.net/{}/{}".format(STORAGE_ACCOUNT_NAME, 
                                                                  CONTAINER_NAME,
                                                                  'validation.csv')

# %%
# !azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation.csv \
        --source-key 'owUPSqTbwAigV54BHTr8oYABEha8xi/VsA4HD06GboDgOb3pf6OFgtw/tlKYv/AlkgSIBkxqoA28hnkIeo4NFg==' \
        --destination  $destination_url \
        --dest-key $storage_account_key --quiet
# Out:
# =Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 0 B; Average Speed:0 B/s.                                 Finished: 0 file(s), 1.844 MB; Average Speed:186.67 KB/s.                      Finished: 1 file(s), 1.844 MB; Average Speed:155.14 KB/s.                                                                                                     Finished 1 of total 1 file(s).
#                                                                                [2018/05/20 14:59:55] Transfer summary:
# -----------------
# Total files transferred: 1
# Transfer successfully:   1
# Transfer skipped:        0
# Transfer failed:         0
# Elapsed time:            00.00:00:16

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/ImagenetEstimatorHorovod.py --path scripts

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/timer.py --path scripts

# %%
# !az batchai cluster create \
--name nc24r \
--image UbuntuLTS \
--vm-size Standard_NC24r \
--min 8 --max 8 \
--afs-name $FILESHARE_NAME \
--afs-mount-path extfs \
--container-name $CONTAINER_NAME \
--container-mount-path extcn \
--user-name mat \
--password dnstvxrz \
--storage-account-name $STORAGE_ACCOUNT_NAME \
--storage-account-key $storage_account_key
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "allocationState": "resizing",
#   "allocationStateTransitionTime": "2018-05-20T15:32:13.933000+00:00",
#   "creationTime": "2018-05-20T15:32:13.933000+00:00",
#   "currentNodeCount": 0,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": [
#         {
#           "accountName": "batchfcab5890st",
#           "containerName": "batchfcab5890container",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "mountOptions": null,
#           "relativeMountPath": "extcn"
#         }
#       ],
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": null,
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 0,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-20T15:32:17.762000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 8
#     }
#   },
#   "subnet": null,
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster show -n nc24r
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# {
#   "allocationState": "steady",
#   "allocationStateTransitionTime": "2018-05-20T11:39:27.473000+00:00",
#   "creationTime": "2018-05-20T11:37:19.346000+00:00",
#   "currentNodeCount": 8,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": null,
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": [
#         {
#           "fileServer": {
#             "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#             "resourceGroup": "batchfcab5890rg"
#           },
#           "mountOptions": "rw",
#           "relativeMountPath": "nfs",
#           "sourceDirectory": null
#         }
#       ],
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 8,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-20T11:37:21.602000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 8
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name    Resource Group    VM Size         State      Idle    Running    Preparing    Leaving    Unusable
# ------  ----------------  --------------  -------  ------  ---------  -----------  ---------  ----------
# nc24r   batchfcab5890rg   STANDARD_NC24r  steady        8          0            0          0           0

# %%
# !az batchai cluster list-nodes -n nc24r -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# ID                                IP                Port
# --------------------------------  --------------  ------
# tvm-587366007_1-20180520t153402z  138.91.120.162   50001
# tvm-587366007_2-20180520t153402z  138.91.120.162   50005
# tvm-587366007_3-20180520t153402z  138.91.120.162   50000
# tvm-587366007_4-20180520t153402z  138.91.120.162   50004
# tvm-587366007_5-20180520t153402z  138.91.120.162   50003
# tvm-587366007_6-20180520t153402z  138.91.120.162   50007
# tvm-587366007_7-20180520t153402z  138.91.120.162   50002
# tvm-587366007_8-20180520t153402z  138.91.120.162   50006

# %%
jobs_dict = {
  "$schema": "https://raw.githubusercontent.com/Azure/BatchAI/master/schemas/2017-09-01-preview/job.json",
  "properties": {
    "nodeCount": 8,
    "customToolkitSettings": {
      "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh; \
      echo $AZ_BATCH_HOST_LIST; \
      ls $AZ_BATCHAI_INPUT_TRAIN;\
      ls $AZ_BATCHAI_MOUNT_ROOT;\
      mpirun -n 32 -ppn 4 -hosts $AZ_BATCH_HOST_LIST \
      -env I_MPI_FABRICS=dapl \
      -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0 \
      -env I_MPI_DYNAMIC_CONNECTION=0 \
      -env DISTRIBUTED=True \
      -genvall \
      python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetEstimatorHorovod.py"
    },
    "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
    "inputDirectories": [{
        "id": "SCRIPTS",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
      },
      {
        "id": "TRAIN",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/extcn",
      },
      {
        "id": "TEST",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/extcn",
      },
    ],
    "outputDirectories": [{
        "id": "MODEL",
        "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
        "pathSuffix": "Models"
    }],
    "containerSettings": {
      "imageSourceRegistry": {
        "image": "masalvar/horovod-intel"
      }
    }
  }
}

# %%
write_json_to_file(jobs_dict, 'job.json')

# %%
# !az batchai job create -n horovod_benchmark --cluster-name nc24r -c job.json
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "caffeSettings": null,
#   "chainerSettings": null,
#   "cluster": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#     "resourceGroup": "batchfcab5890rg"
#   },
#   "cntkSettings": null,
#   "constraints": {
#     "maxWallClockTime": "7 days, 0:00:00"
#   },
#   "containerSettings": {
#     "imageSourceRegistry": {
#       "credentials": null,
#       "image": "masalvar/horovod-intel",
#       "serverUrl": null
#     }
#   },
#   "creationTime": "2018-05-20T15:46:11.610000+00:00",
#   "customToolkitSettings": {
#     "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh;       echo $AZ_BATCH_HOST_LIST;       ls $AZ_BATCHAI_INPUT_TRAIN;      ls $AZ_BATCHAI_MOUNT_ROOT;      mpirun -n 32 -ppn 4 -hosts $AZ_BATCH_HOST_LIST       -env I_MPI_FABRICS=dapl       -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0       -env I_MPI_DYNAMIC_CONNECTION=0       -env DISTRIBUTED=True       -genvall       python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetEstimatorHorovod.py"
#   },
#   "environmentVariables": null,
#   "executionInfo": {
#     "endTime": null,
#     "errors": null,
#     "exitCode": null,
#     "startTime": "2018-05-20T15:46:14.581000+00:00"
#   },
#   "executionState": "running",
#   "executionStateTransitionTime": "2018-05-20T15:46:14.754000+00:00",
#   "experimentName": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/jobs/horovod_benchmark",
#   "inputDirectories": [
#     {
#       "id": "SCRIPTS",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
#     },
#     {
#       "id": "TRAIN",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/extcn"
#     },
#     {
#       "id": "TEST",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/extcn"
#     }
#   ],
#   "jobPreparation": null,
#   "location": null,
#   "name": "horovod_benchmark",
#   "nodeCount": 8,
#   "outputDirectories": [
#     {
#       "createNew": true,
#       "id": "MODEL",
#       "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#       "pathSuffix": "Models",
#       "type": "custom"
#     }
#   ],
#   "priority": 0,
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-20T15:46:13.346000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#   "tags": null,
#   "tensorFlowSettings": null,
#   "toolType": "custom",
#   "type": "Microsoft.BatchAI/Jobs"
# }

# %%
 # !az batchai job list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name               Resource Group    Cluster    Cluster RG       Tool      Nodes  State      Exit code
# -----------------  ----------------  ---------  ---------------  ------  -------  -------  -----------
# horovod_benchmark  batchfcab5890rg   nc24r      batchfcab5890rg  custom        2  failed             1

# %%
# !az batchai job list-files --name horovod_benchmark --output-directory-id stdouterr
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# [
#   {
#     "contentLength": 25951,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_1-20180520t144145z.log?sv=2016-05-31&sr=f&sig=vrOzOHpTPVXHiLwxkSB%2BH8xaCmnIrDXh4fFeHGkYBC4%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:34+00:00",
#     "name": "execution-tvm-1392786932_1-20180520t144145z.log"
#   },
#   {
#     "contentLength": 24933,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_2-20180520t144145z.log?sv=2016-05-31&sr=f&sig=IqJc5z0%2FsWwawHHwIJjChDogspPrG1nM%2FY5lY3VDYJk%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:27+00:00",
#     "name": "execution-tvm-1392786932_2-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25361,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_3-20180520t144145z.log?sv=2016-05-31&sr=f&sig=NSro2e29%2Flrjk6Gz7K%2FV7UabCEXNOCI%2F46BTcyk0UeM%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:27+00:00",
#     "name": "execution-tvm-1392786932_3-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25134,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_4-20180520t144145z.log?sv=2016-05-31&sr=f&sig=gH%2F0JT6l5KjiniXnPaJ7YnGArSQ6oiMXeizs7zvVrNo%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:29+00:00",
#     "name": "execution-tvm-1392786932_4-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25163,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_5-20180520t144145z.log?sv=2016-05-31&sr=f&sig=ePgPdiJpDch42o1IVdaE74g%2BeKUWDiG9sIFBZGm%2FxNY%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:27+00:00",
#     "name": "execution-tvm-1392786932_5-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25454,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_6-20180520t144145z.log?sv=2016-05-31&sr=f&sig=D0c8Nh4eRlqmTbIGhs7DqZQsLEskc6cTRAX8kxRIEjA%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:27+00:00",
#     "name": "execution-tvm-1392786932_6-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25592,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_7-20180520t144145z.log?sv=2016-05-31&sr=f&sig=AlERh4Gtguo1SPcDA0yKH22OK1CWoPea0csMXkU7hPU%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:28+00:00",
#     "name": "execution-tvm-1392786932_7-20180520t144145z.log"
#   },
#   {
#     "contentLength": 25179,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/execution-tvm-1392786932_8-20180520t144145z.log?sv=2016-05-31&sr=f&sig=w6KZO0CvHr7ZQcgQlhmvL52Jk710cb%2BB%2F5ACvmVH0Zk%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:27+00:00",
#     "name": "execution-tvm-1392786932_8-20180520t144145z.log"
#   },
#   {
#     "contentLength": 66044,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/stderr.txt?sv=2016-05-31&sr=f&sig=%2FHqxeremEs2BZBQ4Dy2cr7D4wIeSW6Ly8nbCgXnJ4F0%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:34+00:00",
#     "name": "stderr.txt"
#   },
#   {
#     "contentLength": 85,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batchfcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/b3a500a7-1a70-4045-b8f7-d35f7a3c1240/stdout.txt?sv=2016-05-31&sr=f&sig=mAMzSjesjXM2OW8X70HMonzJe%2FWk%2F7Ls1sEJ83rE2VE%3D&se=2018-05-20T16%3A04%3A03Z&sp=rl",
#     "lastModified": "2018-05-20T15:02:30+00:00",
#     "name": "stdout.txt"
#   }
# ]

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stderr.txt
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:__main__:Runnin Distributed
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading training data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Reading validation data info
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_num_worker_replicas': 1, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_master': '', '_evaluation_master': '', '_log_step_count_steps': 100, '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_is_chief': True, '_task_type': 'worker', '_keep_checkpoint_max': 5, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_tf_random_seed': None, '_global_id_in_cluster': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fae275e92e8>, '_service': None, '_task_id': 0}
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f79e820d390>, '_save_checkpoints_steps': 10000, '_master': '', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_keep_checkpoint_max': 5, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_service': None, '_keep_checkpoint_every_n_hours': 10000, '_num_ps_replicas': 0, '_evaluation_master': '', '_global_id_in_cluster': 0, '_task_type': 'worker', '_save_checkpoints_secs': None, '_log_step_count_steps': 100, '_save_summary_steps': 100, '_is_chief': True, '_num_worker_replicas': 1, '_tf_random_seed': None, '_task_id': 0}
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': 10000, '_save_checkpoints_secs': None, '_service': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_num_ps_replicas': 0, '_tf_random_seed': None, '_num_worker_replicas': 1, '_master': '', '_log_step_count_steps': 100, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdc997df278>, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_task_type': 'worker', '_evaluation_master': '', '_global_id_in_cluster': 0, '_keep_checkpoint_max': 5, '_task_id': 0, '_is_chief': True}
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f166f167748>, '_keep_checkpoint_max': 5, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_tf_random_seed': None, '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_global_id_in_cluster': 0, '_service': None, '_log_step_count_steps': 100, '_master': '', '_save_checkpoints_secs': None, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_task_type': 'worker', '_is_chief': True, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000}
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Training...
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_save_checkpoints_secs': None, '_task_type': 'worker', '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f153b069358>, '_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_steps': 10000, '_task_id': 0, '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_log_step_count_steps': 100, '_save_summary_steps': 100, '_service': None, '_tf_random_seed': None, '_keep_checkpoint_max': 5}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': None, '_task_id': 0, '_master': '', '_save_checkpoints_steps': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_task_type': 'worker', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_service': None, '_log_step_count_steps': 100, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f062010f240>, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': None, '_global_id_in_cluster': 0, '_evaluation_master': '', '_save_summary_steps': 100}
# INFO:__main__:Training...
# INFO:tensorflow:Using config: {'_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_evaluation_master': '', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_save_checkpoints_secs': None, '_master': '', '_save_checkpoints_steps': 10000, '_log_step_count_steps': 100, '_task_type': 'worker', '_tf_random_seed': None, '_num_ps_replicas': 0, '_task_id': 0, '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f13bd81d160>, '_num_worker_replicas': 1, '_service': None}
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:tensorflow:Using config: {'_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_worker_replicas': 1, '_num_ps_replicas': 0, '_task_type': 'worker', '_global_id_in_cluster': 0, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_log_step_count_steps': 100, '_save_summary_steps': 100, '_service': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_task_id': 0, '_save_checkpoints_steps': 10000, '_save_checkpoints_secs': None, '_master': '', '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f899ffa7390>}
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_service': None, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_task_id': 0, '_save_checkpoints_steps': 10000, '_keep_checkpoint_max': 5, '_tf_random_seed': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f763cbea710>, '_save_summary_steps': 100, '_num_ps_replicas': 0, '_task_type': 'worker', '_global_id_in_cluster': 0, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_worker_replicas': 1, '_master': '', '_log_step_count_steps': 100, '_is_chief': True}
# INFO:tensorflow:Using config: {'_is_chief': True, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_num_worker_replicas': 1, '_tf_random_seed': None, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbe72567240>, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_evaluation_master': '', '_keep_checkpoint_every_n_hours': 10000, '_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_task_type': 'worker', '_save_checkpoints_steps': 10000, '_service': None}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3446ae7278>, '_service': None, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_evaluation_master': '', '_global_id_in_cluster': 0, '_task_type': 'worker', '_save_checkpoints_steps': 10000, '_keep_checkpoint_every_n_hours': 10000, '_master': '', '_tf_random_seed': None, '_task_id': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_keep_checkpoint_max': 5, '_is_chief': True, '_num_ps_replicas': 0, '_save_checkpoints_secs': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_is_chief': True, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_save_checkpoints_steps': 10000, '_task_type': 'worker', '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f77dcd81208>, '_keep_checkpoint_every_n_hours': 10000, '_num_ps_replicas': 0, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_summary_steps': 100, '_service': None, '_task_id': 0, '_master': '', '_global_id_in_cluster': 0, '_num_worker_replicas': 1, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_tf_random_seed': None}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_task_type': 'worker', '_task_id': 0, '_save_summary_steps': 100, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_ps_replicas': 0, '_log_step_count_steps': 100, '_tf_random_seed': None, '_master': '', '_global_id_in_cluster': 0, '_save_checkpoints_steps': 10000, '_service': None, '_num_worker_replicas': 1, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f02ecd81128>, '_is_chief': True, '_save_checkpoints_secs': None}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_log_step_count_steps': 100, '_master': '', '_task_id': 0, '_tf_random_seed': None, '_is_chief': True, '_save_checkpoints_steps': 10000, '_task_type': 'worker', '_keep_checkpoint_max': 5, '_save_summary_steps': 100, '_global_id_in_cluster': 0, '_save_checkpoints_secs': None, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_worker_replicas': 1, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe6b820d748>, '_num_ps_replicas': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# }
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Training...
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f02cd59e710>, '_evaluation_master': '', '_num_ps_replicas': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_save_checkpoints_secs': None, '_keep_checkpoint_max': 5, '_task_type': 'worker', '_save_checkpoints_steps': 10000, '_master': '', '_service': None, '_num_worker_replicas': 1, '_task_id': 0, '_tf_random_seed': None, '_log_step_count_steps': 100, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_summary_steps': 100, '_global_id_in_cluster': 0}
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fe949e63278>, '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_global_id_in_cluster': 0, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None, '_is_chief': True, '_master': '', '_evaluation_master': '', '_log_step_count_steps': 100, '_save_summary_steps': 100, '_service': None, '_tf_random_seed': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_task_id': 0}
# INFO:tensorflow:Using config: {'_service': None, '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100, '_task_id': 0, '_num_worker_replicas': 1, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5914f41240>, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_max': 5, '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_task_type': 'worker', '_is_chief': True}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:tensorflow:Using config: {'_log_step_count_steps': 100, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f327c50d278>, '_save_checkpoints_steps': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_tf_random_seed': None, '_num_ps_replicas': 0, '_save_summary_steps': 100, '_global_id_in_cluster': 0, '_task_type': 'worker', '_task_id': 0, '_keep_checkpoint_max': 5, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_service': None, '_is_chief': True, '_num_worker_replicas': 1, '_save_checkpoints_secs': None}
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_tf_random_seed': None, '_master': '', '_save_checkpoints_secs': None, '_task_type': 'worker', '_model_dir': '/mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/d520d680-e24c-4a23-8dde-c9d62f5b77cf/outputs/Models', '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_save_summary_steps': 100, '_num_worker_replicas': 1, '_keep_checkpoint_max': 5, '_is_chief': True, '_service': None, '_global_id_in_cluster': 0, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f923bee90f0>}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f744c44f2b0>, '_num_worker_replicas': 1, '_master': '', '_evaluation_master': '', '_task_id': 0, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_global_id_in_cluster': 0, '_service': None, '_keep_checkpoint_every_n_hours': 10000, '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_is_chief': True, '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_tf_random_seed': None, '_log_step_count_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_task_type': 'worker', '_keep_checkpoint_max': 5}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:tensorflow:Using config: {'_evaluation_master': '', '_num_ps_replicas': 0, '_master': '', '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_task_id': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_log_step_count_steps': 100, '_save_checkpoints_steps': 10000, '_num_worker_replicas': 1, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_save_checkpoints_secs': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f5a1b569320>, '_tf_random_seed': None, '_save_summary_steps': 100, '_service': None}
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_num_worker_replicas': 1, '_task_type': 'worker', '_evaluation_master': '', '_num_ps_replicas': 0, '_service': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_max': 5, '_master': '', '_save_summary_steps': 100, '_save_checkpoints_secs': None, '_global_id_in_cluster': 0, '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbc96e22278>, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_tf_random_seed': None, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_is_chief': True, '_save_checkpoints_steps': 10000}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_task_type': 'worker', '_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_tf_random_seed': None, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6e2c62b320>, '_task_id': 0, '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_num_ps_replicas': 0, '_save_checkpoints_steps': 10000, '_master': '', '_keep_checkpoint_max': 5, '_num_worker_replicas': 1, '_save_summary_steps': 100, '_log_step_count_steps': 100, '_global_id_in_cluster': 0, '_service': None}
# INFO:tensorflow:Using config: {'_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f68990490f0>, '_keep_checkpoint_every_n_hours': 10000, '_task_type': 'worker', '_keep_checkpoint_max': 5, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_tf_random_seed': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_service': None, '_save_checkpoints_steps': 10000, '_master': '', '_global_id_in_cluster': 0, '_log_step_count_steps': 100, '_is_chief': True, '_save_checkpoints_secs': None, '_save_summary_steps': 100, '_evaluation_master': ''}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_master': '', '_save_summary_steps': 100, '_task_type': 'worker', '_log_step_count_steps': 100, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f8800053208>, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_worker_replicas': 1, '_global_id_in_cluster': 0, '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_keep_checkpoint_max': 5, '_save_checkpoints_secs': None, '_tf_random_seed': None, '_is_chief': True, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_task_id': 0, '_service': None}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_is_chief': True, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "3"
# }
# , '_task_id': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f64e3fa7320>, '_num_ps_replicas': 0, '_evaluation_master': '', '_task_type': 'worker', '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_master': '', '_num_worker_replicas': 1, '_save_summary_steps': 100, '_global_id_in_cluster': 0, '_tf_random_seed': None, '_save_checkpoints_steps': 10000, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd'}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:tensorflow:Using config: {'_task_id': 0, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_is_chief': True, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_ps_replicas': 0, '_task_type': 'worker', '_save_checkpoints_secs': None, '_tf_random_seed': None, '_save_checkpoints_steps': 10000, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fdc13629240>, '_num_worker_replicas': 1, '_evaluation_master': '', '_master': '', '_global_id_in_cluster': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_save_summary_steps': 100}
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Creating estimator with params: {'classes': 1000, 'learning_rate': 0.001}
# INFO:__main__:Training...
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Training...
# INFO:tensorflow:Using config: {'_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f6a9b629240>, '_num_worker_replicas': 1, '_master': '', '_task_type': 'worker', '_save_summary_steps': 100, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_max': 5, '_service': None, '_save_checkpoints_secs': None, '_save_checkpoints_steps': 10000, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_is_chief': True, '_num_ps_replicas': 0, '_global_id_in_cluster': 0, '_evaluation_master': '', '_task_id': 0, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "0"
# }
# , '_tf_random_seed': None}
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_task_type': 'worker', '_tf_random_seed': None, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_num_ps_replicas': 0, '_task_id': 0, '_log_step_count_steps': 100, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_save_checkpoints_secs': None, '_save_checkpoints_steps': 10000, '_num_worker_replicas': 1, '_global_id_in_cluster': 0, '_service': None, '_keep_checkpoint_every_n_hours': 10000, '_evaluation_master': '', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fefcc62b2b0>, '_master': '', '_is_chief': True, '_save_summary_steps': 100}
# INFO:tensorflow:Using config: {'_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_evaluation_master': '', '_save_checkpoints_steps': 10000, '_keep_checkpoint_every_n_hours': 10000, '_keep_checkpoint_max': 5, '_is_chief': True, '_task_type': 'worker', '_global_id_in_cluster': 0, '_save_summary_steps': 100, '_master': '', '_log_step_count_steps': 100, '_service': None, '_tf_random_seed': None, '_save_checkpoints_secs': None, '_num_worker_replicas': 1, '_task_id': 0, '_num_ps_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fd869d63160>, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd'}
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Training...
# INFO:__main__:Creating estimator with params: {'learning_rate': 0.001, 'classes': 1000}
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:tensorflow:Using config: {'_keep_checkpoint_every_n_hours': 10000, '_service': None, '_task_id': 0, '_master': '', '_save_checkpoints_steps': 10000, '_tf_random_seed': None, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_evaluation_master': '', '_num_ps_replicas': 0, '_log_step_count_steps': 100, '_task_type': 'worker', '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f0e8bce9128>, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "1"
# }
# , '_save_summary_steps': 100, '_is_chief': True, '_save_checkpoints_secs': None, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_task_type': 'worker', '_num_ps_replicas': 0, '_evaluation_master': '', '_log_step_count_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbce8dc0278>, '_save_summary_steps': 100, '_keep_checkpoint_max': 5, '_global_id_in_cluster': 0, '_task_id': 0, '_num_worker_replicas': 1, '_is_chief': True, '_model_dir': '/mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd', '_keep_checkpoint_every_n_hours': 10000, '_session_config': gpu_options {
#   allow_growth: true
#   visible_device_list: "2"
# }
# , '_save_checkpoints_secs': None, '_service': None, '_save_checkpoints_steps': 10000, '_master': '', '_tf_random_seed': None}
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Training...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /mnt/batch/tasks/shared/LS_root/mounts/extfs/scripts/ImagenetEstimatorHorovod.py:137: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/slim/python/slim/nets/resnet_v1.py:210: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# ...
# INFO:tensorflow:global_step/sec: 0.508904
# INFO:tensorflow:step = 401, loss = 5.442087 (196.499 sec)
# INFO:tensorflow:step = 401, loss = 5.7510834 (196.500 sec)
# INFO:tensorflow:loss = 5.6859913, step = 401 (196.500 sec)
# INFO:tensorflow:loss = 5.603615, step = 401 (196.500 sec)
# INFO:tensorflow:step = 401, loss = 5.777555 (196.499 sec)
# INFO:tensorflow:step = 401, loss = 5.7930813 (196.499 sec)
# INFO:tensorflow:step = 401, loss = 5.605172 (196.499 sec)
# INFO:tensorflow:loss = 5.548317, step = 401 (196.500 sec)
# INFO:tensorflow:loss = 5.7089863, step = 401 (196.498 sec)
# INFO:tensorflow:step = 401, loss = 5.6959333 (196.501 sec)
# INFO:tensorflow:step = 401, loss = 5.309334 (196.500 sec)
# INFO:tensorflow:step = 401, loss = 5.8019805 (196.500 sec)
# INFO:tensorflow:step = 401, loss = 5.8382134 (196.499 sec)
# INFO:tensorflow:loss = 5.650218, step = 401 (196.500 sec)
# INFO:tensorflow:loss = 5.68239, step = 401 (196.483 sec)
# INFO:tensorflow:loss = 5.8272743, step = 401 (196.501 sec)
# INFO:tensorflow:loss = 5.8205223, step = 401 (196.451 sec)
# INFO:tensorflow:step = 401, loss = 5.3151345 (196.501 sec)
# INFO:tensorflow:global_step/sec: 0.508842
# INFO:tensorflow:loss = 5.657365, step = 401 (196.500 sec)
# INFO:tensorflow:step = 401, loss = 5.9197364 (196.499 sec)
# INFO:tensorflow:loss = 5.487725, step = 401 (196.500 sec)
# INFO:tensorflow:global_step/sec: 0.508905
# INFO:tensorflow:step = 401, loss = 5.857718 (196.500 sec)
# INFO:tensorflow:loss = 5.872627, step = 401 (196.500 sec)
# INFO:tensorflow:step = 401, loss = 5.549152 (196.525 sec)
# INFO:tensorflow:loss = 5.92044, step = 401 (196.500 sec)
# INFO:tensorflow:loss = 5.5582914, step = 401 (196.499 sec)
# INFO:tensorflow:loss = 5.3443747, step = 401 (196.499 sec)
# INFO:tensorflow:step = 401, loss = 5.72042 (196.500 sec)
# INFO:tensorflow:loss = 5.405641, step = 401 (196.501 sec)
# INFO:tensorflow:global_step/sec: 0.499704
# INFO:tensorflow:global_step/sec: 0.499701
# INFO:tensorflow:global_step/sec: 0.499709
# INFO:tensorflow:global_step/sec: 0.499704
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499705
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:global_step/sec: 0.499704
# INFO:tensorflow:global_step/sec: 0.499704
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:step = 501, loss = 5.1250954 (200.120 sec)
# INFO:tensorflow:global_step/sec: 0.499705
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:global_step/sec: 0.499704
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:loss = 5.4699526, step = 501 (200.118 sec)
# INFO:tensorflow:global_step/sec: 0.4997
# INFO:tensorflow:global_step/sec: 0.499705
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:step = 501, loss = 5.3415875 (200.116 sec)
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:step = 501, loss = 5.4792337 (200.118 sec)
# INFO:tensorflow:loss = 5.503517, step = 501 (200.119 sec)
# INFO:tensorflow:step = 501, loss = 5.506774 (200.118 sec)
# INFO:tensorflow:global_step/sec: 0.499701
# INFO:tensorflow:step = 501, loss = 5.294855 (200.119 sec)
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499702
# INFO:tensorflow:global_step/sec: 0.499703
# INFO:tensorflow:loss = 5.5224905, step = 501 (200.119 sec)
# INFO:tensorflow:global_step/sec: 0.499698
# INFO:tensorflow:global_step/sec: 0.499769
# INFO:tensorflow:step = 501, loss = 5.296965 (200.120 sec)
# INFO:tensorflow:step = 501, loss = 5.0630617 (200.119 sec)
# INFO:tensorflow:loss = 5.247116, step = 501 (200.119 sec)
# INFO:tensorflow:step = 501, loss = 5.1793513 (200.119 sec)
# INFO:tensorflow:loss = 5.1786957, step = 501 (200.119 sec)
# INFO:tensorflow:global_step/sec: 0.49966
# INFO:tensorflow:step = 501, loss = 5.4647512 (200.120 sec)
# INFO:tensorflow:loss = 5.199071, step = 501 (200.118 sec)
# INFO:tensorflow:loss = 5.56055, step = 501 (200.120 sec)
# INFO:tensorflow:loss = 5.471609, step = 501 (200.119 sec)
# INFO:tensorflow:loss = 5.6645827, step = 501 (200.119 sec)
# INFO:tensorflow:step = 501, loss = 5.4720106 (200.119 sec)
# INFO:tensorflow:loss = 5.16383, step = 501 (200.119 sec)
# INFO:tensorflow:loss = 5.26538, step = 501 (200.107 sec)
# INFO:tensorflow:step = 501, loss = 5.350783 (200.121 sec)
# INFO:tensorflow:step = 501, loss = 5.4854207 (200.117 sec)
# INFO:tensorflow:loss = 5.821887, step = 501 (200.119 sec)
# INFO:tensorflow:global_step/sec: 0.499698
# INFO:tensorflow:loss = 5.3346524, step = 501 (200.119 sec)
# INFO:tensorflow:loss = 4.8473644, step = 501 (200.119 sec)
# INFO:tensorflow:loss = 5.3010435, step = 501 (200.118 sec)
# INFO:tensorflow:step = 501, loss = 5.3705873 (200.092 sec)
# INFO:tensorflow:loss = 5.157035, step = 501 (200.120 sec)
# INFO:tensorflow:step = 501, loss = 5.4153767 (200.122 sec)
# INFO:tensorflow:step = 501, loss = 5.3465195 (200.120 sec)
# INFO:tensorflow:step = 501, loss = 5.5434294 (200.120 sec)
# INFO:tensorflow:global_step/sec: 0.50367
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503671
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.50367
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.50367
# INFO:tensorflow:global_step/sec: 0.503671
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:step = 601, loss = 5.2275987 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.50367
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.50367
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503672
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:loss = 5.203423, step = 601 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.503669
# INFO:tensorflow:global_step/sec: 0.503667
# INFO:tensorflow:global_step/sec: 0.503714
# INFO:tensorflow:loss = 5.1809464, step = 601 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.503668
# INFO:tensorflow:loss = 5.091612, step = 601 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 5.4761057 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.503667
# INFO:tensorflow:global_step/sec: 0.503666
# INFO:tensorflow:loss = 5.6330495, step = 601 (198.543 sec)
# INFO:tensorflow:loss = 5.516194, step = 601 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 4.919154 (198.544 sec)
# INFO:tensorflow:step = 601, loss = 4.9967413 (198.543 sec)
# INFO:tensorflow:loss = 5.3596535, step = 601 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 5.3334436 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 4.972207 (198.542 sec)
# INFO:tensorflow:loss = 5.311495, step = 601 (198.542 sec)
# INFO:tensorflow:loss = 5.11269, step = 601 (198.544 sec)
# INFO:tensorflow:loss = 5.216036, step = 601 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 5.419506 (198.542 sec)
# INFO:tensorflow:step = 601, loss = 4.8484125 (198.543 sec)
# INFO:tensorflow:step = 601, loss = 4.8842626 (198.543 sec)
# INFO:tensorflow:loss = 5.094374, step = 601 (198.543 sec)
# INFO:tensorflow:loss = 5.2631636, step = 601 (198.544 sec)
# INFO:tensorflow:step = 601, loss = 4.967153 (198.543 sec)
# INFO:tensorflow:loss = 5.138234, step = 601 (198.544 sec)
# INFO:tensorflow:step = 601, loss = 5.5174184 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.503615
# INFO:tensorflow:loss = 5.1389613, step = 601 (198.544 sec)
# INFO:tensorflow:loss = 5.052552, step = 601 (198.543 sec)
# INFO:tensorflow:global_step/sec: 0.503672
# INFO:tensorflow:global_step/sec: 0.503665
# INFO:tensorflow:step = 601, loss = 5.1650224 (198.544 sec)
# INFO:tensorflow:step = 601, loss = 4.7900105 (198.542 sec)
# INFO:tensorflow:loss = 5.338297, step = 601 (198.569 sec)
# INFO:tensorflow:step = 601, loss = 5.2584043 (198.564 sec)
# INFO:tensorflow:step = 601, loss = 5.064971 (198.542 sec)
# INFO:tensorflow:loss = 4.8835945, step = 601 (198.547 sec)
# INFO:tensorflow:step = 601, loss = 5.0577345 (198.544 sec)
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/d520d680-e24c-4a23-8dde-c9d62f5b77cf/outputs/Models/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 625 into /mnt/batch/tasks/shared/LS_root/jobs/horovod_benchmark/wd/model.ckpt.
# INFO:tensorflow:Loss for final step: 5.25614.
# INFO:__main__:Training took 1618.870 seconds
# INFO:tensorflow:Loss for final step: 4.8944216.
# INFO:__main__:Training took 1619.816 seconds
# INFO:tensorflow:Loss for final step: 5.345804.
# INFO:__main__:Training took 1619.902 seconds
# INFO:tensorflow:Loss for final step: 5.2081976.
# INFO:__main__:Training took 1620.016 seconds
# INFO:tensorflow:Loss for final step: 4.597257.
# INFO:__main__:Training took 1620.069 seconds
# INFO:tensorflow:Loss for final step: 5.2193193.
# INFO:__main__:Training took 1620.380 seconds
# INFO:tensorflow:Loss for final step: 5.0178413.
# INFO:__main__:Training took 1620.355 seconds
# INFO:tensorflow:Loss for final step: 4.8324337.
# INFO:__main__:Training took 1620.568 seconds
# INFO:tensorflow:Loss for final step: 5.3111935.
# INFO:__main__:Training took 1621.586 seconds
# INFO:tensorflow:Loss for final step: 5.0435266.
# INFO:__main__:Training took 1623.083 seconds
# INFO:tensorflow:Loss for final step: 5.078935.
# INFO:__main__:Training took 1623.562 seconds
# INFO:tensorflow:Loss for final step: 5.3045354.
# INFO:__main__:Training took 1623.693 seconds
# INFO:tensorflow:Loss for final step: 5.001101.
# INFO:tensorflow:Loss for final step: 5.2335076.
# INFO:__main__:Training took 1623.580 seconds
# INFO:__main__:Training took 1623.553 seconds
# INFO:tensorflow:Loss for final step: 5.225529.
# INFO:__main__:Training took 1623.692 seconds
# INFO:tensorflow:Loss for final step: 4.737844.
# INFO:__main__:Training took 1624.128 seconds
# INFO:tensorflow:Loss for final step: 5.4087734.
# INFO:__main__:Training took 1624.347 seconds
# INFO:tensorflow:Loss for final step: 5.026219.
# INFO:__main__:Training took 1626.527 seconds
# INFO:tensorflow:Loss for final step: 4.958136.
# INFO:tensorflow:Loss for final step: 5.215475.
# INFO:__main__:Training took 1626.557 seconds
# INFO:__main__:Training took 1626.512 seconds
# INFO:tensorflow:Loss for final step: 5.1856227.
# INFO:__main__:Training took 1627.056 seconds
# INFO:tensorflow:Loss for final step: 5.390851.
# INFO:__main__:Training took 1627.019 seconds
# INFO:tensorflow:Loss for final step: 5.295985.
# INFO:tensorflow:Loss for final step: 5.0659103.
# INFO:tensorflow:Loss for final step: 5.15178.
# INFO:__main__:Training took 1627.125 seconds
# INFO:__main__:Training took 1627.308 seconds
# INFO:__main__:Training took 1627.290 seconds
# INFO:tensorflow:Loss for final step: 5.168831.
# INFO:__main__:Training took 1629.647 seconds
# INFO:tensorflow:Loss for final step: 4.712775.
# INFO:__main__:Training took 1629.954 seconds
# INFO:tensorflow:Loss for final step: 5.487027.
# INFO:__main__:Training took 1630.032 seconds
# INFO:tensorflow:Loss for final step: 5.0329623.
# INFO:__main__:Training took 1629.820 seconds
# INFO:tensorflow:Loss for final step: 5.0536456.
# INFO:__main__:Training took 1630.286 seconds
# INFO:tensorflow:Loss for final step: 4.930035.
# INFO:__main__:Training took 1630.802 seconds
# INFO:tensorflow:Loss for final step: 5.485264.
# INFO:__main__:Training took 1638.689 seconds
# INFO:__main__:Testing...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-20-16:15:49
# INFO:tensorflow:Graph was finalized.
# 2018-05-20 16:15:49.755313: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-20 16:15:49.755532: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 2749 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 3490:00:00.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from /mnt/batch/tasks/shared/LS_root/mounts/extfs/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/d520d680-e24c-4a23-8dde-c9d62f5b77cf/outputs/Models/model.ckpt-625
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# ^C

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stdout.txt
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# 10.0.0.4,10.0.0.5,10.0.0.6,10.0.0.7,10.0.0.8,10.0.0.9,10.0.0.10,10.0.0.11
# train
# train.csv
# validation
# validation.csv
# extcn
# extfs
# ^C

# %%
# !az batchai job delete --name horovod_benchmark -y
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
#  - Finished ..

# %%
# !az configure --defaults group=''
# !az configure --defaults location=''

# %%
# !az batchai cluster delete --name nc24r -g $GROUP_NAME -y
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
#  - Finished ..

# %%
# !az batchai file-server delete -n $NFS_NAME -y -g $GROUP_NAME
# Out:
#  - Finished ..

# %%
# !az group delete --name $GROUP_NAME -y
# Out:
#  - Finished ..
