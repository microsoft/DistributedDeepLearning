# %%
# !az login -o table
# Out:
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code ABNVKQJ47 to authenticate.
# CloudName    Name                           State    TenantId                              IsDefault
# -----------  -----------------------------  -------  ------------------------------------  -----------
# AzureCloud   Boston DS Dev                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Azure Internal - London        Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Danielle Internal         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47  True
# AzureCloud   Visual Studio Enterprise       Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Boston Engineering             Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   ADLTrainingMS                  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyExt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Ads Eng Big Data Subscription  Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling Preview         Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Data Wrangling development     Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   AzureML Client PROD            Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   R portal - Production          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   PhillyInt                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Project Vienna Demo 1          Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Solution Template Testing      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Team Ilan                      Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
# AzureCloud   Marketing Automation           Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47

# %%
# !az provider register -n Microsoft.BatchAI
# !az provider register -n Microsoft.Batch

# %%
# !az account list -o table
# Out:
# Name                           CloudName    SubscriptionId                        State    IsDefault
# -----------------------------  -----------  ------------------------------------  -------  -----------
# Boston DS Dev                  AzureCloud   0ca618d2-22a8-413a-96d0-0f1b531129c3  Enabled
# Azure Internal - London        AzureCloud   1ba81249-8edd-4619-a486-3d28a2176aad  Enabled
# Team Danielle Internal         AzureCloud   edf507a2-6235-46c5-b560-fd463ba2e771  Enabled  True
# Visual Studio Enterprise       AzureCloud   fb11e9eb-22e1-4347-8d0a-84ef60157664  Enabled
# Boston Engineering             AzureCloud   bc4170f0-cc6e-49d2-ba65-bc00a7a4df6b  Enabled
# ADLTrainingMS                  AzureCloud   ace74b35-b0de-428b-a1d9-55459d7a6e30  Enabled
# Data Wrangling Preview         AzureCloud   215613ac-9dfb-488c-be46-c387e999b127  Enabled
# Data Wrangling development     AzureCloud   35f16a99-532a-4a47-9e93-00305f6c40f2  Enabled
# AzureML Client PROD            AzureCloud   4a0f8d7f-c197-476b-95e1-fafcd77f12e4  Enabled
# R portal - Production          AzureCloud   2569dcd9-a995-4b78-ae22-58a1015fd0f7  Enabled
# PhillyExt                      AzureCloud   a20c82c7-4497-4d44-952a-3105f790e26b  Enabled
# Solution Template Testing      AzureCloud   3bcfa59c-82a0-44f9-ac08-b3479370bace  Enabled
# Team Ilan                      AzureCloud   ff18d7a8-962a-406c-858f-49acd23d6c01  Enabled
# Marketing Automation           AzureCloud   03909a66-bef8-4d52-8e9a-a346604e0902  Enabled
# Ads Eng Big Data Subscription  AzureCloud   d4231148-f093-4473-85de-8c4d19247495  Enabled
# PhillyInt                      AzureCloud   d50e5f6b-6c27-4ab1-8587-3d85cef6426e  Enabled
# Project Vienna Demo 1          AzureCloud   75f78a03-482f-4fd8-8c71-5ddc08f92726  Enabled
# UST Container Registration     AzureCloud   1f65a667-2b81-49ca-aea3-f8dd9fd3e1d9  Enabled
# ASutton Subscription           AzureCloud   10d0b7c6-9243-4713-91a9-2730375d3a1b  Enabled

# %%
# !az account set -s "ASutton Subscription"

# %%
# !az --version
# Out:
# azure-cli (2.0.24)
#
# acr (2.0.18)
# acs (2.0.23)
# advisor (0.1.1)
# appservice (0.1.23)
# backup (1.0.4)
# batch (3.1.8)
# batchai (0.1.4)
# billing (0.1.7)
# cdn (0.0.11)
# cloud (2.0.11)
# cognitiveservices (0.1.10)
# command-modules-nspkg (2.0.1)
# configure (2.0.13)
# consumption (0.2.1)
# container (0.1.16)
# core (2.0.24)
# cosmosdb (0.1.16)
# dla (0.0.16)
# dls (0.0.19)
# eventgrid (0.1.7)
# extension (0.0.7)
# feedback (2.0.7)
# find (0.2.8)
# interactive (0.3.12)
# iot (0.1.16)
# keyvault (2.0.16)
# lab (0.0.14)
# monitor (0.0.14)
# network (2.0.20)
# nspkg (3.0.1)
# profile (2.0.17)
# rdbms (0.0.10)
# redis (0.2.11)
# reservations (0.1.1)
# resource (2.0.20)
# role (2.0.16)
# servicefabric (0.0.8)
# sql (2.0.18)
# storage (2.0.22)
# vm (2.0.23)
#
# Python location '/opt/az/bin/python3'
# Extensions directory '/home/mat/.azure/cliextensions'
#
# Python (Linux) 3.6.1 (default, Jan  5 2018, 21:18:08)
# [GCC 4.8.4]
#
# Legal docs and information: aka.ms/AzureCliLegal

# %%
import os
import uuid
import random
import json

def write_json_to_file(json_dict, filename):
    """ Simple function to write JSON dictionaries to files
    """
    with open(filename, 'w') as outfile:
        json.dump(json_dict, outfile)

LOCATION = 'eastus' # We are setting everything up in East US
                    # Be aware that you need to set things up in a region that has GPU VMs (N-Series)

short_uuid = str(uuid.uuid4())[:8]
short_uuid = 'fcab5890'
GROUP_NAME = "batch{uuid}rg".format(uuid=short_uuid)
STORAGE_ACCOUNT_NAME = "batch{uuid}st".format(uuid=short_uuid)
CONTAINER_NAME = "batch{uuid}container".format(uuid=short_uuid)
FILESHARE_NAME = "batch2{uuid}share".format(uuid=short_uuid)
NFS_NAME="batch{uuid}nfs".format(uuid=short_uuid)

# %%
# !az group create -n $GROUP_NAME -o table -l $LOCATION
# Out:
# Location    Name
# ----------  ---------------
# eastus      batch90ab64c3rg

# %%
json_data = !az storage account create -l $LOCATION -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME --sku Standard_LRS
print('Storage account {} provisioning state: {}'.format(STORAGE_ACCOUNT_NAME, json.loads(''.join(json_data))['provisioningState']))
# Out:
# Storage account batch90ab64c3st provisioning state: Succeeded

# %%
json_data = !az storage account keys list -n $STORAGE_ACCOUNT_NAME -g $GROUP_NAME
storage_account_key = json.loads(''.join(json_data))[0]['value']

# %%
# !az storage share create --account-name $STORAGE_ACCOUNT_NAME \
--account-key $storage_account_key --name $FILESHARE_NAME
# Out:
# {
#   "created": true
# }

# %%
# !az storage directory create --share-name $FILESHARE_NAME  --name scripts \
--account-name $STORAGE_ACCOUNT_NAME --account-key $storage_account_key
# Out:
# {
#   "created": true
# }

# %%
# !az configure --defaults location=$LOCATION

# %%
# !az configure --defaults group=$GROUP_NAME

# %%
# %env AZURE_STORAGE_ACCOUNT $STORAGE_ACCOUNT_NAME
# Out:
# env: AZURE_STORAGE_ACCOUNT=batchfcab5890st

# %%
# %env AZURE_STORAGE_KEY=$storage_account_key
# Out:
# env: AZURE_STORAGE_KEY=qTUeM/dh+vIhiKcrYx3EkvJKEOACztR2D7GAxE/5bRXnkxdU1T3e1JyYmbL4Rr43AMt6NMYW3OXPrg0iiyLk1g==

# %% [markdown]
# If you get an error when creating the NFS share below about permissions please run the command below
# ```bash
# !az role assignment create --scope /subscriptions/<YOUR SUBSRIPTION ID> --role "Network Contributor" --assignee 9fcb3732-5f52-4135-8c08-9d4bbaf203ea
# ```

# %%
# !az batchai file-server create -n $NFS_NAME --disk-count 4 --disk-size 250 -s Standard_DS4_v2 -u mat -p d13NHAL! -g $GROUP_NAME -l $LOCATION
# Out:
# Using default 'batch90ab64c3rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "creationTime": "2018-05-20T22:08:13.059000+00:00",
#   "dataDisks": {
#     "cachingType": "none",
#     "diskCount": 4,
#     "diskSizeInGb": 250,
#     "storageAccountType": "Premium_LRS"
#   },
#   "id": "/subscriptions/10d0b7c6-9243-4713-91a9-2730375d3a1b/resourceGroups/batch90ab64c3rg/providers/Microsoft.BatchAI/fileservers/batch90ab64c3nfs",
#   "location": "eastus",
#   "mountSettings": {
#     "fileServerInternalIp": "10.0.0.4",
#     "fileServerPublicIp": "40.114.123.205",
#     "fileServerType": "nfs",
#     "mountPoint": "/data"
#   },
#   "name": "batch90ab64c3nfs",
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-20T22:12:05.366000+00:00",
#   "resourceGroup": "batch90ab64c3rg",
#   "sshConfiguration": {
#     "publicIpsToAllow": null,
#     "userAccountSettings": {
#       "adminUserName": "mat",
#       "adminUserPassword": null,
#       "adminUserSshPublicKey": null
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/10d0b7c6-9243-4713-91a9-2730375d3a1b/resourceGroups/fileserverrg-8635f485-0d7b-4556-b344-02512535564a/providers/Microsoft.Network/virtualNetworks/8635f485-0d7b-4556-b344-02512535564avnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-8635f485-0d7b-4556-b344-02512535564a"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/FileServers",
#   "vmSize": "Standard_DS4_v2"
# }

# %%
# !az batchai file-server list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name              Resource Group    Size             Disks       Public IP     Internal IP    Type    Mount Point
# ----------------  ----------------  ---------------  ----------  ------------  -------------  ------  -------------
# batchfcab5890nfs  batchfcab5890rg   Standard_DS4_v2  4 x 250 Gb  40.114.69.36  10.0.0.4       nfs     /data

# %%
# %%writefile nodeprep.sh
# #!/usr/bin/env bash
# wget https://gist.githubusercontent.com/msalvaris/073c28a9993d58498957294d20d74202/raw/916eefe763c71da49d8ed41cb8474bdc8021af33/install_azcopy
# chmod 777 install_azcopy
# sudo ./install_azcopy
#
# mkdir -p /data/imagenet
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation.csv \
#         --destination  /data/imagenet/validation.csv\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=7x3rN7c/nlXbnZ0gAFywd5Er3r6MdwCq97Vwvda25WE%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/validation.tar.gz \
#         --destination  /data/imagenet/validation.tar.gz\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=zy8L4shZa3XXBe152hPnhXsyfBqCufDOz01a9ZHWU28%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train.csv \
#         --destination  /data/imagenet/train.csv\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=EUcahDDZcefOKtHoVWDh7voAC1BoxYNM512spFmjmDU%3D"\
#         --quiet
#
# azcopy --source https://datasharesa.blob.core.windows.net/imagenet/train.tar.gz \
#         --destination  /data/imagenet/train.tar.gz\
#         --source-sas "?se=2025-01-01&sp=r&sv=2017-04-17&sr=b&sig=qP%2B7lQuFKHo5UhQKpHcKt6p5fHT21lPaLz1O/vv4FNU%3D"\
#         --quiet
#
# cd /data/imagenet
# tar -xvzf train.tar.gz
# tar -xzvf validation.tar.gz
# Out:
# Overwriting nodeprep.sh

# %% [markdown]
# Copy the file over and run it on the NFS VM. This will install azcopy and download and prepare the data
# ```bash
# scp nodeprep.sh mat@<VM_IP>:~/
# ssh mat@<VM_IP> sudo chmod 777 ~/nodeprep.sh
# ssh mat@<VM_IP> ./nodeprep.sh
# ```

# %%
# %%writefile nodeprep.sh
# #!/usr/bin/env bash
# mkdir -p $AZ_BATCHAI_MOUNT_ROOT/imagenet
# rsync --info=progress2 -r $AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/train.tar.gz $AZ_BATCHAI_MOUNT_ROOT/imagenet/
# rsync --info=progress2 -r $AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/train.csv $AZ_BATCHAI_MOUNT_ROOT/imagenet/
# rsync --info=progress2 -r $AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/validation.tar.gz $AZ_BATCHAI_MOUNT_ROOT/imagenet/
# rsync --info=progress2 -r $AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/validation.csv $AZ_BATCHAI_MOUNT_ROOT/imagenet/
# cd $AZ_BATCHAI_MOUNT_ROOT/imagenet
# tar -xzf train.tar.gz
# tar -xzf validation.tar.gz
# Out:
# Overwriting nodeprep.sh

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source nodeprep.sh --path scripts

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/ImagenetKerasHorovod.py --path scripts

# %%
# !az storage file upload --share-name $FILESHARE_NAME --source ../execution/timer.py --path scripts

# %%
cluster_dict = {
    "properties": {
        "nodeSetup": {
            "setupTask": {
                "commandLine": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts/nodeprep.sh",
                "runElevated": True,
                "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
            }
        }
    }
}

# %%
write_json_to_file(cluster_dict, 'cluster.json')

# %%
# !az batchai cluster create \
--name nc24r \
--image UbuntuLTS \
--vm-size Standard_NC24r \
--min 2 --max 2 \
--afs-name $FILESHARE_NAME \
--afs-mount-path extfs \
--user-name mat \
--password dnstvxrz \
--storage-account-name $STORAGE_ACCOUNT_NAME \
--storage-account-key $storage_account_key \
--nfs $NFS_NAME \
--nfs-mount-path nfs
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "allocationState": "resizing",
#   "allocationStateTransitionTime": "2018-05-21T20:41:00.194000+00:00",
#   "creationTime": "2018-05-21T20:41:00.194000+00:00",
#   "currentNodeCount": 0,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": null,
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": [
#         {
#           "fileServer": {
#             "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#             "resourceGroup": "batchfcab5890rg"
#           },
#           "mountOptions": "rw",
#           "relativeMountPath": "nfs",
#           "sourceDirectory": null
#         }
#       ],
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 0,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-21T20:42:17.721000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 2
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster show -n nc24r
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# {
#   "allocationState": "resizing",
#   "allocationStateTransitionTime": "2018-05-21T20:41:00.194000+00:00",
#   "creationTime": "2018-05-21T20:41:00.194000+00:00",
#   "currentNodeCount": 0,
#   "errors": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#   "location": "eastus",
#   "name": "nc24r",
#   "nodeSetup": {
#     "mountVolumes": {
#       "azureBlobFileSystems": null,
#       "azureFileShares": [
#         {
#           "accountName": "batchfcab5890st",
#           "azureFileUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share",
#           "credentials": {
#             "accountKey": null,
#             "accountKeySecretReference": null
#           },
#           "directoryMode": "0777",
#           "fileMode": "0777",
#           "relativeMountPath": "extfs"
#         }
#       ],
#       "fileServers": [
#         {
#           "fileServer": {
#             "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/fileservers/batchfcab5890nfs",
#             "resourceGroup": "batchfcab5890rg"
#           },
#           "mountOptions": "rw",
#           "relativeMountPath": "nfs",
#           "sourceDirectory": null
#         }
#       ],
#       "unmanagedFileSystems": null
#     },
#     "setupTask": null
#   },
#   "nodeStateCounts": {
#     "idleNodeCount": 0,
#     "leavingNodeCount": 0,
#     "preparingNodeCount": 0,
#     "runningNodeCount": 0,
#     "unusableNodeCount": 0
#   },
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-21T20:42:17.721000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "scaleSettings": {
#     "autoScale": null,
#     "manual": {
#       "nodeDeallocationOption": "requeue",
#       "targetNodeCount": 2
#     }
#   },
#   "subnet": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae/providers/Microsoft.Network/virtualNetworks/ecb3eec6-ae81-4fdb-8fb9-0a57266b20aevnet/subnets/Subnet-1",
#     "resourceGroup": "fileserverrg-ecb3eec6-ae81-4fdb-8fb9-0a57266b20ae"
#   },
#   "tags": null,
#   "type": "Microsoft.BatchAI/Clusters",
#   "userAccountSettings": {
#     "adminUserName": "mat",
#     "adminUserPassword": null,
#     "adminUserSshPublicKey": null
#   },
#   "virtualMachineConfiguration": {
#     "imageReference": {
#       "offer": "UbuntuServer",
#       "publisher": "Canonical",
#       "sku": "16.04-LTS",
#       "version": "latest"
#     }
#   },
#   "vmPriority": "dedicated",
#   "vmSize": "STANDARD_NC24r"
# }

# %%
# !az batchai cluster list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name    Resource Group    VM Size         State      Idle    Running    Preparing    Leaving    Unusable
# ------  ----------------  --------------  -------  ------  ---------  -----------  ---------  ----------
# nc24r   batchfcab5890rg   STANDARD_NC24r  steady        2          0            0          0           0

# %%
# !az batchai cluster list-nodes -n nc24r -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
# ID                                 IP             Port
# ---------------------------------  -----------  ------
# tvm-1915592855_1-20180521t204411z  168.61.46.5   50000
# tvm-1915592855_2-20180521t204411z  168.61.46.5   50001

# %%
jobs_dict = {
  "$schema": "https://raw.githubusercontent.com/Azure/BatchAI/master/schemas/2017-09-01-preview/job.json",
  "properties": {
    "nodeCount": 8,
    "customToolkitSettings": {
      "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh; \
      echo $AZ_BATCH_HOST_LIST; \
      mpirun -n 32 -ppn 4 -hosts $AZ_BATCH_HOST_LIST \
      -env I_MPI_FABRICS=dapl \
      -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0 \
      -env I_MPI_DYNAMIC_CONNECTION=0 \
      -env DISTRIBUTED=True \
      -genvall \
      python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetKerasHorovod.py"
    },
    "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
    "inputDirectories": [{
        "id": "SCRIPTS",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
      },
      {
        "id": "TRAIN",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/train",
      },
      {
        "id": "TEST",
        "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/test",
      },
    ],
    "outputDirectories": [{
        "id": "MODEL",
        "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
        "pathSuffix": "Models"
    }],
    "containerSettings": {
      "imageSourceRegistry": {
        "image": "masalvar/horovod-intel-keras"
      }
    }
  }
}

# %%
write_json_to_file(jobs_dict, 'job.json')

# %%
# !az batchai job create -n horovod_benchmark --cluster-name nc24r -c job.json
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Using default 'eastus' for arg location
# {- Finished ..
#   "caffeSettings": null,
#   "chainerSettings": null,
#   "cluster": {
#     "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/clusters/nc24r",
#     "resourceGroup": "batchfcab5890rg"
#   },
#   "cntkSettings": null,
#   "constraints": {
#     "maxWallClockTime": "7 days, 0:00:00"
#   },
#   "containerSettings": {
#     "imageSourceRegistry": {
#       "credentials": null,
#       "image": "masalvar/horovod-intel-keras",
#       "serverUrl": null
#     }
#   },
#   "creationTime": "2018-05-21T18:54:36.823000+00:00",
#   "customToolkitSettings": {
#     "commandLine": "source /opt/intel/compilers_and_libraries_2017.4.196/linux/mpi/intel64/bin/mpivars.sh;       echo $AZ_BATCH_HOST_LIST;       mpirun -n 32 -ppn 4 -hosts $AZ_BATCH_HOST_LIST       -env I_MPI_FABRICS=dapl       -env I_MPI_DAPL_PROVIDER=ofa-v2-ib0       -env I_MPI_DYNAMIC_CONNECTION=0       -env DISTRIBUTED=True       -genvall       python $AZ_BATCHAI_INPUT_SCRIPTS/ImagenetKerasHorovod.py"
#   },
#   "environmentVariables": null,
#   "executionInfo": {
#     "endTime": null,
#     "errors": null,
#     "exitCode": null,
#     "startTime": "2018-05-21T18:54:38.321000+00:00"
#   },
#   "executionState": "running",
#   "executionStateTransitionTime": "2018-05-21T18:54:38.432000+00:00",
#   "experimentName": null,
#   "id": "/subscriptions/edf507a2-6235-46c5-b560-fd463ba2e771/resourceGroups/batchfcab5890rg/providers/Microsoft.BatchAI/jobs/horovod_benchmark",
#   "inputDirectories": [
#     {
#       "id": "SCRIPTS",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/extfs/scripts"
#     },
#     {
#       "id": "TRAIN",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/train"
#     },
#     {
#       "id": "TEST",
#       "path": "$AZ_BATCHAI_MOUNT_ROOT/nfs/imagenet/test"
#     }
#   ],
#   "jobPreparation": null,
#   "location": null,
#   "name": "horovod_benchmark",
#   "nodeCount": 8,
#   "outputDirectories": [
#     {
#       "createNew": true,
#       "id": "MODEL",
#       "pathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#       "pathSuffix": "Models",
#       "type": "custom"
#     }
#   ],
#   "priority": 0,
#   "provisioningState": "succeeded",
#   "provisioningStateTransitionTime": "2018-05-21T18:54:37.792000+00:00",
#   "resourceGroup": "batchfcab5890rg",
#   "stdOutErrPathPrefix": "$AZ_BATCHAI_MOUNT_ROOT/extfs",
#   "tags": null,
#   "tensorFlowSettings": null,
#   "toolType": "custom",
#   "type": "Microsoft.BatchAI/Jobs"
# }

# %%
 # !az batchai job list -o table
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# Name               Resource Group    Cluster    Cluster RG       Tool      Nodes  State
# -----------------  ----------------  ---------  ---------------  ------  -------  -------
# horovod_benchmark  batchfcab5890rg   nc24r      batchfcab5890rg  custom        8  running

# %%
# !az batchai job list-files --name horovod_benchmark --output-directory-id stdouterr
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# [
#   {
#     "contentLength": 23766,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_1-20180521t184456z.log?sv=2016-05-31&sr=f&sig=qtyqBiAfPuzlTplwlaincfaAWn3lNUdHsIjXSd1Jaqk%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:14+00:00",
#     "name": "execution-tvm-1783593343_1-20180521t184456z.log"
#   },
#   {
#     "contentLength": 23125,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_2-20180521t184456z.log?sv=2016-05-31&sr=f&sig=1%2Bh5BnnAq0HGQQ4Mppaivo0qzyRTwLuNCc47s3%2B5Sw0%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:15+00:00",
#     "name": "execution-tvm-1783593343_2-20180521t184456z.log"
#   },
#   {
#     "contentLength": 22885,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_3-20180521t184456z.log?sv=2016-05-31&sr=f&sig=mfHxQ5z3wciJ%2BSVJiG6h%2FNvrQbzGktfJkY3M82Ww11A%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:16+00:00",
#     "name": "execution-tvm-1783593343_3-20180521t184456z.log"
#   },
#   {
#     "contentLength": 23941,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_4-20180521t184456z.log?sv=2016-05-31&sr=f&sig=9RPOaEqphreHxeCPRMVk0qFpg%2BwlQ0Dt3E2tlKTHNgE%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:22+00:00",
#     "name": "execution-tvm-1783593343_4-20180521t184456z.log"
#   },
#   {
#     "contentLength": 23318,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_5-20180521t184456z.log?sv=2016-05-31&sr=f&sig=yrW7oajt1BOOZ29GOu0tkLPeETILO5GFC573QUokEU0%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:17+00:00",
#     "name": "execution-tvm-1783593343_5-20180521t184456z.log"
#   },
#   {
#     "contentLength": 23730,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_6-20180521t184456z.log?sv=2016-05-31&sr=f&sig=xpSqOLWFr%2FQj4Mxs2cFyPsGFS6nWZGKxEuoe3EgdD3E%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:13+00:00",
#     "name": "execution-tvm-1783593343_6-20180521t184456z.log"
#   },
#   {
#     "contentLength": 24515,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_7-20180521t184456z.log?sv=2016-05-31&sr=f&sig=wTjfURczYUThGLd6wjxRmLlGv0PcgGCSQkPUUDSnBFg%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:23+00:00",
#     "name": "execution-tvm-1783593343_7-20180521t184456z.log"
#   },
#   {
#     "contentLength": 24061,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/execution-tvm-1783593343_8-20180521t184456z.log?sv=2016-05-31&sr=f&sig=bSs0jMdbu46XTfsHzVCAh3QKsySwlU7DI0wbXUqjefw%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:14+00:00",
#     "name": "execution-tvm-1783593343_8-20180521t184456z.log"
#   },
#   {
#     "contentLength": 1089,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/stderr.txt?sv=2016-05-31&sr=f&sig=mmRYzCy2T1sL5Lr6yaS5JRjq2vG1F9SylpKH00HmlYQ%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:31+00:00",
#     "name": "stderr.txt"
#   },
#   {
#     "contentLength": 75,
#     "downloadUrl": "https://batchfcab5890st.file.core.windows.net/batch2fcab5890share/edf507a2-6235-46c5-b560-fd463ba2e771/batchfcab5890rg/jobs/horovod_benchmark/be314653-0028-4133-8c20-1905ebd4a977/stdout.txt?sv=2016-05-31&sr=f&sig=DZAcVGWesfKovi7R3lZfIrLynhdvwSwrekl3RGYOv0M%3D&se=2018-05-21T19%3A56%3A31Z&sp=rl",
#     "lastModified": "2018-05-21T18:56:23+00:00",
#     "name": "stdout.txt"
#   }
# ]

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stderr.txt
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# INFO:__main__:Runnin Distributed
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515391: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515078: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:__main__:Tensorflow version 1.6.0
# INFO:__main__:Tensorflow version 1.6.0
# 2018-05-21 18:56:58.514814: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515836: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.514707: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515918: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515429: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515078: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:__main__:Tensorflow version 1.6.0
# 2018-05-21 18:56:58.515407: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:__main__:Tensorflow version 1.6.0
# 2018-05-21 18:56:58.515806: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515057: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515918: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:__main__:Tensorflow version 1.6.0
# 2018-05-21 18:56:58.515225: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515599: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515580: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515042: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515057: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.516162: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515936: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515225: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515599: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515581: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:56:58.515292: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2018-05-21 18:57:00.587675: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: b063:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.587730: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.607421: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 9aa4:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.607478: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.608477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: c505:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.608518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.612313: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 8cdc:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.612356: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.648429: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 8055:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.648488: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.656242: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 71a4:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.656285: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.661926: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 958c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.661982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.662273: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: acf9:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.662314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.714161: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 4f42:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.714217: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.733295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 680c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.733333: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.736593: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 2acb:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.736648: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.736885: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 3b6c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.736924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.775994: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0c31:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.776047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.782603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: e1ca:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.782657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.783110: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0d3f:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.788344: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 26e2:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.783173: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.788384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.784086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: f3a3:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.796576: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: fe92:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.784128: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.796629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.787588: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 218c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.796732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 3c62:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.787628: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.796784: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.858338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: e63f:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.858397: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.859326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 1754:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.859384: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.863047: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 2c8c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.863086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.870408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: f733:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.870472: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.903547: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: c763:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.903607: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.909982: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: dac6:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.910036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.917555: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: f508:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.917594: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 3
# 2018-05-21 18:57:00.919590: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 85fa:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.921400: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: c908:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.919647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.921454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:00.920157: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: b15c:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.921742: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 0c7e:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.920202: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 2
# 2018-05-21 18:57:00.921782: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 0
# 2018-05-21 18:57:00.921287: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1212] Found device 0 with properties:
# name: Tesla V100-PCIE-16GB major: 7 minor: 0 memoryClockRate(GHz): 1.38
# pciBusID: 9bd8:00:00.0
# totalMemory: 15.78GiB freeMemory: 15.33GiB
# 2018-05-21 18:57:00.921339: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1312] Adding visible gpu devices: 1
# 2018-05-21 18:57:01.032658: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: b063:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.044961: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 9aa4:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.050258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 8cdc:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.052434: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: c505:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.093475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 71a4:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.097768: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 8055:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.127251: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 958c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.135266: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: acf9:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.144764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 4f42:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.166132: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: 680c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.185088: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 3b6c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.187510: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 2acb:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.242408: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0c31:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.243700: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: e1ca:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.253560: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: 3c62:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.259999: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: fe92:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.264671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: f3a3:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.276647: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 218c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.288724: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0d3f:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.290696: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 26e2:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.310449: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 1754:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.312935: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: e63f:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.330042: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: f733:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.341629: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 2c8c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.369169: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: dac6:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.371563: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: c908:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.372794: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 2, name: Tesla V100-PCIE-16GB, pci bus id: b15c:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.371860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: f508:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.373080: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 3, name: Tesla V100-PCIE-16GB, pci bus id: c763:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.372122: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 0c7e:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.392837: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 1, name: Tesla V100-PCIE-16GB, pci bus id: 9bd8:00:00.0, compute capability: 7.0)
# 2018-05-21 18:57:01.404299: I tensorflow/core/common_runtime/gpu/gpu_device.cc:993] Creating TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14847 MB memory) -> physical GPU (device: 0, name: Tesla V100-PCIE-16GB, pci bus id: 85fa:00:00.0, compute capability: 7.0)
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Creating model
# INFO:__main__:Rank: 1 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 0 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 3 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 2 Cluster Size 32
# INFO:__main__:Training...
# INFO:__main__:Rank: 1 Cluster Size 32
Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 755.632 seconds
# INFO:__main__:Training took 761.004 seconds
# INFO:__main__:Training took 757.061 seconds
# INFO:__main__:Training took 752.823 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19660800 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18481152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 37093376 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 39976960 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34865152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# INFO:__main__:Training took 755.215 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 756.104 seconds
# INFO:__main__:Training took 757.337 seconds
# INFO:__main__:Training took 755.139 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 756.429 seconds
# INFO:__main__:Training took 751.549 seconds
# INFO:__main__:Training took 755.178 seconds
# INFO:__main__:Training took 754.302 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 755.906 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 755.898 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2555904 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 751.896 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1835008 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# INFO:__main__:Training took 755.320 seconds
# INFO:__main__:Training took 759.222 seconds
# INFO:__main__:Training took 756.011 seconds
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 19660800 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18481152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 37093376 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 39976960 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 34865152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.5/dist-packages/PIL/TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 10.
#   warnings.warn(str(msg))
# INFO:__main__:Training took 754.656 seconds
# INFO:__main__:Training took 760.474 seconds
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7f97dad04240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7fe055bd1278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7fc85cde4240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7fb3d56b8240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7f40b9287278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/c_api_util.py", line 31, in __init__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7f9ef5e6b240>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7f30d1ceb278>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/c_api_util.py", line 31, in __init__
# TypeError: 'NoneType' object is not callable
# INFO:__main__:Training took 778.023 seconds
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x7fb53f741208>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py", line 712, in __del__
# TypeError: 'NoneType' object is not callable
# ^C

# %%
# !az batchai job stream-file --job-name horovod_benchmark --output-directory-id stdouterr --name stdout.txt
# Out:
# Using default 'batchfcab5890rg' for arg resource_group
# 10.0.0.5,10.0.0.6,10.0.0.7,10.0.0.8,10.0.0.9,10.0.0.10,10.0.0.11,10.0.0.12
# Found 1281167 images belonging to 1000 classes.
# Epoch 1/1
#
#   1/625 [..............................] - ETA: 3:46:00 - loss: 8.4399 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0312
#   2/625 [..............................] - ETA: 1:55:15 - loss: 8.5220 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0156
#   3/625 [..............................] - ETA: 1:18:13 - loss: 8.6386 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0156
#   4/625 [..............................] - ETA: 59:40 - loss: 8.6086 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0156
#   5/625 [..............................] - ETA: 48:33 - loss: 8.6233 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0125
#   6/625 [..............................] - ETA: 41:08 - loss: 8.5783 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0104
#   7/625 [..............................] - ETA: 35:52 - loss: 8.5454 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0089
#   8/625 [..............................] - ETA: 31:56 - loss: 8.5312 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0098
#   9/625 [..............................] - ETA: 28:52 - loss: 8.5272 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0087
#  10/625 [..............................] - ETA: 26:24 - loss: 8.5122 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0078
#  11/625 [..............................] - ETA: 24:22 - loss: 8.4922 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0085
#  12/625 [..............................] - ETA: 22:40 - loss: 8.4989 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0078
#  13/625 [..............................] - ETA: 21:15 - loss: 8.4727 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0072
#  14/625 [..............................] - ETA: 20:01 - loss: 8.4635 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0089
#  15/625 [..............................] - ETA: 18:59 - loss: 8.4457 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0083
#  16/625 [..............................] - ETA: 18:09 - loss: 8.4275 - acc: 0.0000e+00 - top_k_categorical_accuracy: 0.0078
# 616/625 [============================>.] - ETA: 10s - loss: 7.8375 - acc: 0.0033 - top_k_categorical_accuracy: 0.0133
# 617/625 [============================>.] - ETA: 9s - loss: 7.8374 - acc: 0.0033 - top_k_categorical_accuracy: 0.0133
# 618/625 [============================>.] - ETA: 8s - loss: 7.8370 - acc: 0.0033 - top_k_categorical_accuracy: 0.0133
# 619/625 [============================>.] - ETA: 7s - loss: 7.8367 - acc: 0.0033 - top_k_categorical_accuracy: 0.0134
# 620/625 [============================>.] - ETA: 5s - loss: 7.8365 - acc: 0.0033 - top_k_categorical_accuracy: 0.0134
# 621/625 [============================>.] - ETA: 4s - loss: 7.8361 - acc: 0.0033 - top_k_categorical_accuracy: 0.0135
# 622/625 [============================>.] - ETA: 3s - loss: 7.8358 - acc: 0.0033 - top_k_categorical_accuracy: 0.0135
# 623/625 [============================>.] - ETA: 2s - loss: 7.8355 - acc: 0.0033 - top_k_categorical_accuracy: 0.0135
# 624/625 [============================>.] - ETA: 1s - loss: 7.8349 - acc: 0.0034 - top_k_categorical_accuracy: 0.0136
# 625/625 [==============================] - 732s 1s/step - loss: 7.8348 - acc: 0.0034 - top_k_categorical_accuracy: 0.0137
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# Found 1281167 images belonging to 1000 classes.
# ^C

# %%
# !az batchai job delete --name horovod_benchmark -y
# Out:
# Using default 'batchfcab5890rg' for arg resource_group_name
#  - Finished ..

# %%
# !az configure --defaults group=''
# !az configure --defaults location=''

# %%
# !az batchai cluster delete --name nc24r -g $GROUP_NAME -y
# Out:
#  - Finished ..

# %%
# !az batchai file-server delete -n $NFS_NAME -y -g $GROUP_NAME
# Out:
# Using default 'batch6c03bc15rg' for arg resource_group_name
#  - Finished ..

# %%
# !az group delete --name $GROUP_NAME -y
# Out:
# Using default 'batch6c03bc15rg' for arg resource_group_name
#  - Finished ..
